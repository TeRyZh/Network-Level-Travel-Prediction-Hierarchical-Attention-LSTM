# %%
# prompt: mount google drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# prompt: change dir to /content/drive/MyDrive/Hierarchical LSTM for Traffic Prediction/Bigscity-LibCity

# %cd /content/drive/MyDrive/Hierarchical\ LSTM\ for\ Traffic\ Prediction/Bigscity-LibCity
# Out:
# /content/drive/MyDrive/Hierarchical LSTM for Traffic Prediction/Bigscity-LibCity

# %%
# !pip install torch==2.2.2 torchvision==0.17.2 torchaudio==2.2.2
# !pip install ray
# !pip install torchdiffeq
# !pip install einops
# Out:
# Requirement already satisfied: torch==2.2.2 in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: torchvision==0.17.2 in /usr/local/lib/python3.10/dist-packages (0.17.2)
# Requirement already satisfied: torchaudio==2.2.2 in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.2.2) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.2) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.2.2) (1.13.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.2.2) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.2) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch==2.2.2) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.2) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.2) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.2) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.2) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.2) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.2) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.2) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.2) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.2) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.2) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.2) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.2) (2.2.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision==0.17.2) (1.25.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision==0.17.2) (9.4.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.2.2) (12.5.82)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.2.2) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.2.2) (1.3.0)
# Requirement already satisfied: ray in /usr/local/lib/python3.10/dist-packages (2.32.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from ray) (8.1.7)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from ray) (3.15.4)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.10/dist-packages (from ray) (4.19.2)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ray) (1.0.8)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from ray) (24.1)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /usr/local/lib/python3.10/dist-packages (from ray) (3.20.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from ray) (6.0.1)
# Requirement already satisfied: aiosignal in /usr/local/lib/python3.10/dist-packages (from ray) (1.3.1)
# Requirement already satisfied: frozenlist in /usr/local/lib/python3.10/dist-packages (from ray) (1.4.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from ray) (2.31.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray) (0.19.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->ray) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->ray) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->ray) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->ray) (2024.7.4)
# Requirement already satisfied: torchdiffeq in /usr/local/lib/python3.10/dist-packages (0.2.4)
# Requirement already satisfied: torch>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from torchdiffeq) (2.2.2)
# Requirement already satisfied: scipy>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from torchdiffeq) (1.11.4)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from scipy>=1.4.0->torchdiffeq) (1.25.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.0->torchdiffeq) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.0->torchdiffeq) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.0->torchdiffeq) (1.13.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.0->torchdiffeq) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.0->torchdiffeq) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.0->torchdiffeq) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.0->torchdiffeq) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.0->torchdiffeq) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.0->torchdiffeq) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.0->torchdiffeq) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.0->torchdiffeq) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.0->torchdiffeq) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.0->torchdiffeq) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.0->torchdiffeq) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.0->torchdiffeq) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.0->torchdiffeq) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.0->torchdiffeq) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.0->torchdiffeq) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.5.0->torchdiffeq) (12.5.82)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.5.0->torchdiffeq) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.5.0->torchdiffeq) (1.3.0)
# Requirement already satisfied: einops in /usr/local/lib/python3.10/dist-packages (0.8.0)

# %%
# !python run_model.py --task traffic_state_pred --model HierAttnLstm --dataset PEMS_BAY --config_file HierAttnLstm_128_2_2
# Out:
# 2024-07-21 04:36:23,642 - INFO - Log directory: ./libcity/log
# 2024-07-21 04:36:23,643 - INFO - Begin pipeline, task=traffic_state_pred, model_name=HierAttnLstm, dataset_name=PEMS_BAY, exp_id=430
# 2024-07-21 04:36:23,644 - INFO - {'task': 'traffic_state_pred', 'model': 'HierAttnLstm', 'dataset': 'PEMS_BAY', 'saved_model': True, 'train': True, 'seed': 0, 'input_window': 48, 'output_window': 6, 'device': device(type='cuda', index=0), 'hidden_size': 128, 'num_layers': 2, 'dropout': 0.1, 'natt_hops': 2, 'nfc': 512, 'max_up_len': 80, 'dataset_class': 'TrafficStatePointDataset', 'executor': 'TrafficStateExecutor', 'evaluator': 'TrafficStateEvaluator', 'batch_size': 32, 'cache_dataset': True, 'num_workers': 0, 'pad_with_last_sample': True, 'train_rate': 0.7, 'eval_rate': 0.1, 'scaler': 'minmax01', 'load_external': False, 'normal_external': False, 'ext_scaler': 'none', 'add_time_in_day': False, 'add_day_in_week': False, 'robustness_test': False, 'noise_type': 'gaussian', 'disturb_rate': 0.5, 'noise_mean': [5], 'noise_SD': [10], 'gpu': True, 'gpu_id': 0, 'max_epoch': 100, 'train_loss': 'none', 'epoch': 0, 'learner': 'adam', 'learning_rate': 0.01, 'weight_decay': 0, 'lr_epsilon': 1e-08, 'lr_beta1': 0.9, 'lr_beta2': 0.999, 'lr_alpha': 0.99, 'lr_momentum': 0, 'lr_decay': False, 'lr_scheduler': 'multisteplr', 'lr_decay_ratio': 0.1, 'steps': [5, 20, 40, 70], 'step_size': 10, 'lr_T_max': 30, 'lr_eta_min': 0, 'lr_patience': 10, 'lr_threshold': 0.0001, 'clip_grad_norm': False, 'max_grad_norm': 1.0, 'use_early_stop': True, 'patience': 10, 'log_level': 'INFO', 'log_every': 1, 'load_best_epoch': True, 'hyper_tune': False, 'metrics': ['MAE', 'MAPE', 'MSE', 'RMSE', 'masked_MAE', 'masked_MAPE', 'masked_MSE', 'masked_RMSE', 'R2', 'EVAR'], 'evaluator_mode': 'single', 'save_mode': ['csv'], 'geo': {'including_types': ['Point'], 'Point': {}}, 'rel': {'including_types': ['geo'], 'geo': {'cost': 'num'}}, 'dyna': {'including_types': ['state'], 'state': {'entity_id': 'geo_id', 'traffic_speed': 'num'}}, 'data_col': ['traffic_speed'], 'weight_col': 'cost', 'data_files': ['PEMS_BAY'], 'geo_file': 'PEMS_BAY', 'rel_file': 'PEMS_BAY', 'output_dim': 1, 'time_intervals': 300, 'init_weight_inf_or_zero': 'inf', 'set_weight_link_or_dist': 'dist', 'calculate_weight_adj': True, 'weight_adj_epsilon': 0.1, 'exp_id': 430}
# self.scaler_type  minmax01
# 2024-07-21 04:36:24,450 - INFO - Loaded file PEMS_BAY.geo, num_nodes=325
# 2024-07-21 04:36:25,442 - INFO - set_weight_link_or_dist: dist
# 2024-07-21 04:36:25,442 - INFO - init_weight_inf_or_zero: inf
# 2024-07-21 04:36:25,456 - INFO - Loaded file PEMS_BAY.rel, shape=(325, 325)
# 2024-07-21 04:36:25,456 - INFO - Start Calculate the weight by Gauss kernel!
# 2024-07-21 04:36:25,459 - INFO - Loading file PEMS_BAY.dyna
# 2024-07-21 04:36:41,910 - INFO - Loaded file PEMS_BAY.dyna, shape=(52116, 325, 1)
# 2024-07-21 04:36:50,866 - INFO - Dataset created
# 2024-07-21 04:36:50,867 - INFO - x shape: (52063, 48, 325, 1), y shape: (52063, 6, 325, 1)
# 2024-07-21 04:36:50,882 - INFO - train	x: (36444, 48, 325, 1), y: (36444, 6, 325, 1)
# 2024-07-21 04:36:50,882 - INFO - eval	x: (5206, 48, 325, 1), y: (5206, 6, 325, 1)
# 2024-07-21 04:36:50,882 - INFO - test	x: (10413, 48, 325, 1), y: (10413, 6, 325, 1)
# 2024-07-21 04:44:58,441 - INFO - Saved at ./libcity/cache/dataset_cache/point_based_PEMS_BAY_48_6_0.7_0.1_minmax01_32_False_False_False_True.npz
# 2024-07-21 04:44:59,281 - INFO - MinMax01Scaler max: 85.1, min: 0.0
# 2024-07-21 04:44:59,281 - INFO - NoneScaler
# 2024-07-21 04:45:05.057433: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-07-21 04:45:05.100291: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-21 04:45:05.100343: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-21 04:45:05.101780: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-21 04:45:05.108494: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-21 04:45:06.442263: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-07-21 04:45:07,759 - INFO - HierAttnLstm(
#   (lstm_cells): ModuleList(
#     (0): LSTMCell(325, 128)
#     (1): LSTMCell(128, 128)
#   )
#   (hidden_state_pooling): ModuleList(
#     (0): SelfAttentionPooling(
#       (W): Linear(in_features=128, out_features=1, bias=True)
#     )
#   )
#   (cell_state_pooling): ModuleList(
#     (0): SelfAttentionPooling(
#       (W): Linear(in_features=128, out_features=1, bias=True)
#     )
#   )
#   (self_attention): SelfAttention(
#     (ut_dense): Sequential(
#       (0): Linear(in_features=128, out_features=128, bias=True)
#       (1): Tanh()
#     )
#     (et_dense): Linear(in_features=128, out_features=2, bias=True)
#     (softmax): Softmax(dim=-1)
#   )
#   (fc_layer): Sequential(
#     (0): Linear(in_features=256, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=325, bias=True)
#   )
# )
# 2024-07-21 04:45:07,759 - INFO - lstm_cells.0.weight_ih	torch.Size([512, 325])	cuda:0	True
# 2024-07-21 04:45:07,759 - INFO - lstm_cells.0.weight_hh	torch.Size([512, 128])	cuda:0	True
# 2024-07-21 04:45:07,759 - INFO - lstm_cells.0.bias_ih	torch.Size([512])	cuda:0	True
# 2024-07-21 04:45:07,760 - INFO - lstm_cells.0.bias_hh	torch.Size([512])	cuda:0	True
# 2024-07-21 04:45:07,760 - INFO - lstm_cells.1.weight_ih	torch.Size([512, 128])	cuda:0	True
# 2024-07-21 04:45:07,760 - INFO - lstm_cells.1.weight_hh	torch.Size([512, 128])	cuda:0	True
# 2024-07-21 04:45:07,760 - INFO - lstm_cells.1.bias_ih	torch.Size([512])	cuda:0	True
# 2024-07-21 04:45:07,760 - INFO - lstm_cells.1.bias_hh	torch.Size([512])	cuda:0	True
# 2024-07-21 04:45:07,760 - INFO - hidden_state_pooling.0.W.weight	torch.Size([1, 128])	cuda:0	True
# 2024-07-21 04:45:07,760 - INFO - hidden_state_pooling.0.W.bias	torch.Size([1])	cuda:0	True
# 2024-07-21 04:45:07,760 - INFO - cell_state_pooling.0.W.weight	torch.Size([1, 128])	cuda:0	True
# 2024-07-21 04:45:07,760 - INFO - cell_state_pooling.0.W.bias	torch.Size([1])	cuda:0	True
# 2024-07-21 04:45:07,760 - INFO - self_attention.ut_dense.0.weight	torch.Size([128, 128])	cuda:0	True
# 2024-07-21 04:45:07,761 - INFO - self_attention.ut_dense.0.bias	torch.Size([128])	cuda:0	True
# 2024-07-21 04:45:07,761 - INFO - self_attention.et_dense.weight	torch.Size([2, 128])	cuda:0	True
# 2024-07-21 04:45:07,761 - INFO - self_attention.et_dense.bias	torch.Size([2])	cuda:0	True
# 2024-07-21 04:45:07,761 - INFO - fc_layer.0.weight	torch.Size([512, 256])	cuda:0	True
# 2024-07-21 04:45:07,761 - INFO - fc_layer.0.bias	torch.Size([512])	cuda:0	True
# 2024-07-21 04:45:07,761 - INFO - fc_layer.2.weight	torch.Size([325, 512])	cuda:0	True
# 2024-07-21 04:45:07,761 - INFO - fc_layer.2.bias	torch.Size([325])	cuda:0	True
# 2024-07-21 04:45:07,761 - INFO - Total parameter numbers: 680393
# 2024-07-21 04:45:07,761 - INFO - You select `adam` optimizer.
# 2024-07-21 04:45:07,762 - WARNING - Received none train loss func and will use the loss func defined in the model.
# 2024-07-21 04:45:07,762 - INFO - Start training ...
# 2024-07-21 04:45:07,762 - INFO - num_batches:1139
# 2024-07-21 04:48:54,562 - INFO - epoch complete!
# 2024-07-21 04:48:54,563 - INFO - evaluating now!
# 2024-07-21 04:49:03,878 - INFO - Epoch [0/100] train_loss: 5.2746, val_loss: 5.2525, lr: 0.010000, 236.12s
# 2024-07-21 04:49:03,913 - INFO - Saved model at 0
# 2024-07-21 04:49:03,914 - INFO - Val loss decrease from inf to 5.2525, saving to ./libcity/cache/430/model_cache/HierAttnLstm_PEMS_BAY_epoch0.tar
# 2024-07-21 04:52:48,519 - INFO - epoch complete!
# 2024-07-21 04:52:48,519 - INFO - evaluating now!
# 2024-07-21 04:52:57,667 - INFO - Epoch [1/100] train_loss: 4.5649, val_loss: 5.3045, lr: 0.010000, 233.75s
# 2024-07-21 04:56:41,916 - INFO - epoch complete!
# 2024-07-21 04:56:41,917 - INFO - evaluating now!
# 2024-07-21 04:56:51,098 - INFO - Epoch [2/100] train_loss: 4.5369, val_loss: 5.2011, lr: 0.010000, 233.43s
# 2024-07-21 04:56:51,133 - INFO - Saved model at 2
# 2024-07-21 04:56:51,133 - INFO - Val loss decrease from 5.2525 to 5.2011, saving to ./libcity/cache/430/model_cache/HierAttnLstm_PEMS_BAY_epoch2.tar
# 2024-07-21 05:00:35,855 - INFO - epoch complete!
# 2024-07-21 05:00:35,856 - INFO - evaluating now!
# 2024-07-21 05:00:44,996 - INFO - Epoch [3/100] train_loss: 4.5228, val_loss: 5.1641, lr: 0.010000, 233.86s
# 2024-07-21 05:00:45,039 - INFO - Saved model at 3
# 2024-07-21 05:00:45,040 - INFO - Val loss decrease from 5.2011 to 5.1641, saving to ./libcity/cache/430/model_cache/HierAttnLstm_PEMS_BAY_epoch3.tar
# 2024-07-21 05:04:29,263 - INFO - epoch complete!
# 2024-07-21 05:04:29,264 - INFO - evaluating now!
# 2024-07-21 05:04:38,443 - INFO - Epoch [4/100] train_loss: 4.4997, val_loss: 5.1396, lr: 0.010000, 233.40s
# 2024-07-21 05:04:38,479 - INFO - Saved model at 4
# 2024-07-21 05:04:38,480 - INFO - Val loss decrease from 5.1641 to 5.1396, saving to ./libcity/cache/430/model_cache/HierAttnLstm_PEMS_BAY_epoch4.tar
# 2024-07-21 05:08:22,497 - INFO - epoch complete!
# 2024-07-21 05:08:22,498 - INFO - evaluating now!
# 2024-07-21 05:08:31,610 - INFO - Epoch [5/100] train_loss: 4.4876, val_loss: 5.1539, lr: 0.010000, 233.13s
# 2024-07-21 05:12:16,647 - INFO - epoch complete!
# 2024-07-21 05:12:16,647 - INFO - evaluating now!
# 2024-07-21 05:12:25,754 - INFO - Epoch [6/100] train_loss: 4.4875, val_loss: 5.1634, lr: 0.010000, 234.14s
# 2024-07-21 05:16:10,694 - INFO - epoch complete!
# 2024-07-21 05:16:10,695 - INFO - evaluating now!
# 2024-07-21 05:16:19,760 - INFO - Epoch [7/100] train_loss: 4.4729, val_loss: 5.1554, lr: 0.010000, 234.00s
# 2024-07-21 05:20:04,490 - INFO - epoch complete!
# 2024-07-21 05:20:04,490 - INFO - evaluating now!
# 2024-07-21 05:20:13,660 - INFO - Epoch [8/100] train_loss: 4.4703, val_loss: 5.1624, lr: 0.010000, 233.90s
# 2024-07-21 05:23:58,636 - INFO - epoch complete!
# 2024-07-21 05:23:58,637 - INFO - evaluating now!
# 2024-07-21 05:24:07,804 - INFO - Epoch [9/100] train_loss: 4.4674, val_loss: 5.1497, lr: 0.010000, 234.14s
# 2024-07-21 05:27:53,052 - INFO - epoch complete!
# 2024-07-21 05:27:53,052 - INFO - evaluating now!
# 2024-07-21 05:28:02,256 - INFO - Epoch [10/100] train_loss: 4.4674, val_loss: 5.1405, lr: 0.010000, 234.45s
# 2024-07-21 05:31:48,339 - INFO - epoch complete!
# 2024-07-21 05:31:48,339 - INFO - evaluating now!
# 2024-07-21 05:31:57,507 - INFO - Epoch [11/100] train_loss: 4.4686, val_loss: 5.1579, lr: 0.010000, 235.25s
# 2024-07-21 05:35:41,906 - INFO - epoch complete!
# 2024-07-21 05:35:41,907 - INFO - evaluating now!
# 2024-07-21 05:35:51,034 - INFO - Epoch [12/100] train_loss: 4.4681, val_loss: 5.1573, lr: 0.010000, 233.53s
# 2024-07-21 05:39:35,091 - INFO - epoch complete!
# 2024-07-21 05:39:35,091 - INFO - evaluating now!
# 2024-07-21 05:39:44,307 - INFO - Epoch [13/100] train_loss: 4.4676, val_loss: 5.1523, lr: 0.010000, 233.27s
# 2024-07-21 05:43:28,765 - INFO - epoch complete!
# 2024-07-21 05:43:28,765 - INFO - evaluating now!
# 2024-07-21 05:43:37,815 - INFO - Epoch [14/100] train_loss: 4.4682, val_loss: 5.1350, lr: 0.010000, 233.51s
# 2024-07-21 05:43:37,852 - INFO - Saved model at 14
# 2024-07-21 05:43:37,852 - INFO - Val loss decrease from 5.1396 to 5.1350, saving to ./libcity/cache/430/model_cache/HierAttnLstm_PEMS_BAY_epoch14.tar
# 2024-07-21 05:47:19,261 - INFO - epoch complete!
# 2024-07-21 05:47:19,261 - INFO - evaluating now!
# 2024-07-21 05:47:28,216 - INFO - Epoch [15/100] train_loss: 4.4662, val_loss: 5.1485, lr: 0.010000, 230.36s
# 2024-07-21 05:51:09,475 - INFO - epoch complete!
# 2024-07-21 05:51:09,475 - INFO - evaluating now!
# 2024-07-21 05:51:18,465 - INFO - Epoch [16/100] train_loss: 4.4672, val_loss: 5.1353, lr: 0.010000, 230.25s
# 2024-07-21 05:54:58,491 - INFO - epoch complete!
# 2024-07-21 05:54:58,492 - INFO - evaluating now!
# 2024-07-21 05:55:07,397 - INFO - Epoch [17/100] train_loss: 4.4651, val_loss: 5.1364, lr: 0.010000, 228.93s
# 2024-07-21 05:58:48,681 - INFO - epoch complete!
# 2024-07-21 05:58:48,681 - INFO - evaluating now!
# 2024-07-21 05:58:57,585 - INFO - Epoch [18/100] train_loss: 4.4655, val_loss: 5.1826, lr: 0.010000, 230.19s
# 2024-07-21 06:02:38,031 - INFO - epoch complete!
# 2024-07-21 06:02:38,032 - INFO - evaluating now!
# 2024-07-21 06:02:47,012 - INFO - Epoch [19/100] train_loss: 4.4659, val_loss: 5.1561, lr: 0.010000, 229.43s
# 2024-07-21 06:06:28,812 - INFO - epoch complete!
# 2024-07-21 06:06:28,813 - INFO - evaluating now!
# 2024-07-21 06:06:37,772 - INFO - Epoch [20/100] train_loss: 4.4665, val_loss: 5.1689, lr: 0.010000, 230.76s
# 2024-07-21 06:10:20,457 - INFO - epoch complete!
# 2024-07-21 06:10:20,457 - INFO - evaluating now!
# 2024-07-21 06:10:29,372 - INFO - Epoch [21/100] train_loss: 4.4689, val_loss: 5.1617, lr: 0.010000, 231.60s
# 2024-07-21 06:14:09,345 - INFO - epoch complete!
# 2024-07-21 06:14:09,346 - INFO - evaluating now!
# 2024-07-21 06:14:18,310 - INFO - Epoch [22/100] train_loss: 4.4681, val_loss: 5.2081, lr: 0.010000, 228.94s
# 2024-07-21 06:17:58,966 - INFO - epoch complete!
# 2024-07-21 06:17:58,966 - INFO - evaluating now!
# 2024-07-21 06:18:07,807 - INFO - Epoch [23/100] train_loss: 4.4695, val_loss: 5.1532, lr: 0.010000, 229.50s
# 2024-07-21 06:21:47,976 - INFO - epoch complete!
# 2024-07-21 06:21:47,976 - INFO - evaluating now!
# 2024-07-21 06:21:56,902 - INFO - Epoch [24/100] train_loss: 4.4691, val_loss: 5.1494, lr: 0.010000, 229.10s
# 2024-07-21 06:21:56,903 - WARNING - Early stopping at epoch: 24
# 2024-07-21 06:21:56,903 - INFO - Trained totally 25 epochs, average train time is 223.289s, average eval time is 9.067s
# 2024-07-21 06:21:56,923 - INFO - Loaded model at 14
# 2024-07-21 06:21:56,924 - INFO - Saved model at ./libcity/cache/430/model_cache/HierAttnLstm_PEMS_BAY.m
# 2024-07-21 06:21:56,958 - INFO - Start evaluating ...
# 2024-07-21 06:22:18,540 - INFO - Note that you select the single mode to evaluate!
# 2024-07-21 06:22:18,548 - INFO - Evaluate result is saved at ./libcity/cache/430/evaluate_cache/2024_07_21_06_22_18_HierAttnLstm_PEMS_BAY.csv
# 2024-07-21 06:22:18,561 - INFO -
#         MAE  MAPE        MSE      RMSE  ...  masked_MSE  masked_RMSE        R2      EVAR
# 1  4.723972   inf  98.795135  9.939574  ...   98.527374     9.926096 -0.059180  0.038198
# 2  4.723863   inf  98.792305  9.939432  ...   98.524529     9.925952 -0.059168  0.038195
# 3  4.723814   inf  98.790321  9.939332  ...   98.522552     9.925853 -0.059156  0.038190
# 4  4.723805   inf  98.788872  9.939260  ...   98.521118     9.925780 -0.059148  0.038187
# 5  4.723802   inf  98.787277  9.939178  ...   98.519524     9.925700 -0.059142  0.038184
# 6  4.723798   inf  98.785774  9.939103  ...   98.518005     9.925624 -0.059137  0.038180
#
# [6 rows x 10 columns]

# %%
# !python run_model.py --task traffic_state_pred --model HierAttnLstm --dataset PEMS_BAY --config_file HierAttnLstm_128_2_3
# Out:
# Traceback (most recent call last):
#   File "D:\Dropbox\0_Project_Ongoing\Big Data Application for Travel Time prediction\Bigscity-LibCity\run_model.py", line 12, in <module>
#     from libcity.pipeline import run_model
#   File "D:\Dropbox\0_Project_Ongoing\Big Data Application for Travel Time prediction\Bigscity-LibCity\libcity\pipeline\__init__.py", line 1, in <module>
#     from libcity.pipeline.pipeline import run_model, hyper_parameter, objective_function
#   File "D:\Dropbox\0_Project_Ongoing\Big Data Application for Travel Time prediction\Bigscity-LibCity\libcity\pipeline\pipeline.py", line 2, in <module>
#     from ray import tune
# ModuleNotFoundError: No module named 'ray'

# %%
# !python run_model.py --task traffic_state_pred --model HierAttnLstm --dataset PEMS_BAY --config_file HierAttnLstm_128_2_4
# Out:
# 2024-07-21 06:22:23,076 - INFO - Log directory: ./libcity/log
# 2024-07-21 06:22:23,077 - INFO - Begin pipeline, task=traffic_state_pred, model_name=HierAttnLstm, dataset_name=PEMS_BAY, exp_id=56551
# 2024-07-21 06:22:23,077 - INFO - {'task': 'traffic_state_pred', 'model': 'HierAttnLstm', 'dataset': 'PEMS_BAY', 'saved_model': True, 'train': True, 'seed': 0, 'input_window': 48, 'output_window': 6, 'device': device(type='cuda', index=0), 'hidden_size': 128, 'num_layers': 2, 'dropout': 0.1, 'natt_hops': 4, 'nfc': 512, 'max_up_len': 80, 'dataset_class': 'TrafficStatePointDataset', 'executor': 'TrafficStateExecutor', 'evaluator': 'TrafficStateEvaluator', 'batch_size': 32, 'cache_dataset': True, 'num_workers': 0, 'pad_with_last_sample': True, 'train_rate': 0.7, 'eval_rate': 0.1, 'scaler': 'minmax01', 'load_external': False, 'normal_external': False, 'ext_scaler': 'none', 'add_time_in_day': False, 'add_day_in_week': False, 'robustness_test': False, 'noise_type': 'gaussian', 'disturb_rate': 0.5, 'noise_mean': [5], 'noise_SD': [10], 'gpu': True, 'gpu_id': 0, 'max_epoch': 100, 'train_loss': 'none', 'epoch': 0, 'learner': 'adam', 'learning_rate': 0.01, 'weight_decay': 0, 'lr_epsilon': 1e-08, 'lr_beta1': 0.9, 'lr_beta2': 0.999, 'lr_alpha': 0.99, 'lr_momentum': 0, 'lr_decay': False, 'lr_scheduler': 'multisteplr', 'lr_decay_ratio': 0.1, 'steps': [5, 20, 40, 70], 'step_size': 10, 'lr_T_max': 30, 'lr_eta_min': 0, 'lr_patience': 10, 'lr_threshold': 0.0001, 'clip_grad_norm': False, 'max_grad_norm': 1.0, 'use_early_stop': True, 'patience': 10, 'log_level': 'INFO', 'log_every': 1, 'load_best_epoch': True, 'hyper_tune': False, 'metrics': ['MAE', 'MAPE', 'MSE', 'RMSE', 'masked_MAE', 'masked_MAPE', 'masked_MSE', 'masked_RMSE', 'R2', 'EVAR'], 'evaluator_mode': 'single', 'save_mode': ['csv'], 'geo': {'including_types': ['Point'], 'Point': {}}, 'rel': {'including_types': ['geo'], 'geo': {'cost': 'num'}}, 'dyna': {'including_types': ['state'], 'state': {'entity_id': 'geo_id', 'traffic_speed': 'num'}}, 'data_col': ['traffic_speed'], 'weight_col': 'cost', 'data_files': ['PEMS_BAY'], 'geo_file': 'PEMS_BAY', 'rel_file': 'PEMS_BAY', 'output_dim': 1, 'time_intervals': 300, 'init_weight_inf_or_zero': 'inf', 'set_weight_link_or_dist': 'dist', 'calculate_weight_adj': True, 'weight_adj_epsilon': 0.1, 'exp_id': 56551}
# self.scaler_type  minmax01
# 2024-07-21 06:22:23,132 - INFO - Loaded file PEMS_BAY.geo, num_nodes=325
# 2024-07-21 06:22:23,142 - INFO - set_weight_link_or_dist: dist
# 2024-07-21 06:22:23,142 - INFO - init_weight_inf_or_zero: inf
# 2024-07-21 06:22:23,156 - INFO - Loaded file PEMS_BAY.rel, shape=(325, 325)
# 2024-07-21 06:22:23,157 - INFO - Start Calculate the weight by Gauss kernel!
# 2024-07-21 06:22:23,160 - INFO - Loading ./libcity/cache/dataset_cache/point_based_PEMS_BAY_48_6_0.7_0.1_minmax01_32_False_False_False_True.npz
# 2024-07-21 06:22:52,579 - INFO - train	x: (36444, 48, 325, 1), y: (36444, 6, 325, 1)
# 2024-07-21 06:22:52,579 - INFO - eval	x: (5206, 48, 325, 1), y: (5206, 6, 325, 1)
# 2024-07-21 06:22:52,580 - INFO - test	x: (10413, 48, 325, 1), y: (10413, 6, 325, 1)
# 2024-07-21 06:22:53,402 - INFO - MinMax01Scaler max: 85.1, min: 0.0
# 2024-07-21 06:22:53,403 - INFO - NoneScaler
# 2024-07-21 06:22:59.135422: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-07-21 06:22:59.186316: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-21 06:22:59.186368: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-21 06:22:59.187814: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-21 06:22:59.195588: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-21 06:23:00.403529: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-07-21 06:23:01,637 - INFO - HierAttnLstm(
#   (lstm_cells): ModuleList(
#     (0): LSTMCell(325, 128)
#     (1): LSTMCell(128, 128)
#   )
#   (hidden_state_pooling): ModuleList(
#     (0): SelfAttentionPooling(
#       (W): Linear(in_features=128, out_features=1, bias=True)
#     )
#   )
#   (cell_state_pooling): ModuleList(
#     (0): SelfAttentionPooling(
#       (W): Linear(in_features=128, out_features=1, bias=True)
#     )
#   )
#   (self_attention): SelfAttention(
#     (ut_dense): Sequential(
#       (0): Linear(in_features=128, out_features=128, bias=True)
#       (1): Tanh()
#     )
#     (et_dense): Linear(in_features=128, out_features=4, bias=True)
#     (softmax): Softmax(dim=-1)
#   )
#   (fc_layer): Sequential(
#     (0): Linear(in_features=512, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=325, bias=True)
#   )
# )
# 2024-07-21 06:23:01,638 - INFO - lstm_cells.0.weight_ih	torch.Size([512, 325])	cuda:0	True
# 2024-07-21 06:23:01,638 - INFO - lstm_cells.0.weight_hh	torch.Size([512, 128])	cuda:0	True
# 2024-07-21 06:23:01,638 - INFO - lstm_cells.0.bias_ih	torch.Size([512])	cuda:0	True
# 2024-07-21 06:23:01,638 - INFO - lstm_cells.0.bias_hh	torch.Size([512])	cuda:0	True
# 2024-07-21 06:23:01,638 - INFO - lstm_cells.1.weight_ih	torch.Size([512, 128])	cuda:0	True
# 2024-07-21 06:23:01,638 - INFO - lstm_cells.1.weight_hh	torch.Size([512, 128])	cuda:0	True
# 2024-07-21 06:23:01,638 - INFO - lstm_cells.1.bias_ih	torch.Size([512])	cuda:0	True
# 2024-07-21 06:23:01,638 - INFO - lstm_cells.1.bias_hh	torch.Size([512])	cuda:0	True
# 2024-07-21 06:23:01,639 - INFO - hidden_state_pooling.0.W.weight	torch.Size([1, 128])	cuda:0	True
# 2024-07-21 06:23:01,639 - INFO - hidden_state_pooling.0.W.bias	torch.Size([1])	cuda:0	True
# 2024-07-21 06:23:01,639 - INFO - cell_state_pooling.0.W.weight	torch.Size([1, 128])	cuda:0	True
# 2024-07-21 06:23:01,639 - INFO - cell_state_pooling.0.W.bias	torch.Size([1])	cuda:0	True
# 2024-07-21 06:23:01,639 - INFO - self_attention.ut_dense.0.weight	torch.Size([128, 128])	cuda:0	True
# 2024-07-21 06:23:01,639 - INFO - self_attention.ut_dense.0.bias	torch.Size([128])	cuda:0	True
# 2024-07-21 06:23:01,639 - INFO - self_attention.et_dense.weight	torch.Size([4, 128])	cuda:0	True
# 2024-07-21 06:23:01,639 - INFO - self_attention.et_dense.bias	torch.Size([4])	cuda:0	True
# 2024-07-21 06:23:01,639 - INFO - fc_layer.0.weight	torch.Size([512, 512])	cuda:0	True
# 2024-07-21 06:23:01,639 - INFO - fc_layer.0.bias	torch.Size([512])	cuda:0	True
# 2024-07-21 06:23:01,640 - INFO - fc_layer.2.weight	torch.Size([325, 512])	cuda:0	True
# 2024-07-21 06:23:01,640 - INFO - fc_layer.2.bias	torch.Size([325])	cuda:0	True
# 2024-07-21 06:23:01,640 - INFO - Total parameter numbers: 811723
# 2024-07-21 06:23:01,640 - INFO - You select `adam` optimizer.
# 2024-07-21 06:23:01,640 - WARNING - Received none train loss func and will use the loss func defined in the model.
# 2024-07-21 06:23:01,641 - INFO - Start training ...
# 2024-07-21 06:23:01,641 - INFO - num_batches:1139
# 2024-07-21 06:26:47,678 - INFO - epoch complete!
# 2024-07-21 06:26:47,679 - INFO - evaluating now!
# 2024-07-21 06:26:56,971 - INFO - Epoch [0/100] train_loss: 6.6158, val_loss: 4.4899, lr: 0.010000, 235.33s
# 2024-07-21 06:26:57,014 - INFO - Saved model at 0
# 2024-07-21 06:26:57,014 - INFO - Val loss decrease from inf to 4.4899, saving to ./libcity/cache/56551/model_cache/HierAttnLstm_PEMS_BAY_epoch0.tar
# 2024-07-21 06:30:42,966 - INFO - epoch complete!
# 2024-07-21 06:30:42,966 - INFO - evaluating now!
# 2024-07-21 06:30:52,185 - INFO - Epoch [1/100] train_loss: 3.3966, val_loss: 3.6529, lr: 0.010000, 235.17s
# 2024-07-21 06:30:52,226 - INFO - Saved model at 1
# 2024-07-21 06:30:52,226 - INFO - Val loss decrease from 4.4899 to 3.6529, saving to ./libcity/cache/56551/model_cache/HierAttnLstm_PEMS_BAY_epoch1.tar
# 2024-07-21 06:34:36,666 - INFO - epoch complete!
# 2024-07-21 06:34:36,667 - INFO - evaluating now!
# 2024-07-21 06:34:45,820 - INFO - Epoch [2/100] train_loss: 2.8169, val_loss: 2.7772, lr: 0.010000, 233.59s
# 2024-07-21 06:34:45,861 - INFO - Saved model at 2
# 2024-07-21 06:34:45,861 - INFO - Val loss decrease from 3.6529 to 2.7772, saving to ./libcity/cache/56551/model_cache/HierAttnLstm_PEMS_BAY_epoch2.tar
# 2024-07-21 06:38:29,725 - INFO - epoch complete!
# 2024-07-21 06:38:29,725 - INFO - evaluating now!
# 2024-07-21 06:38:38,870 - INFO - Epoch [3/100] train_loss: 2.6163, val_loss: 2.9630, lr: 0.010000, 233.01s
# 2024-07-21 06:42:24,130 - INFO - epoch complete!
# 2024-07-21 06:42:24,130 - INFO - evaluating now!
# 2024-07-21 06:42:33,301 - INFO - Epoch [4/100] train_loss: 2.5616, val_loss: 2.9441, lr: 0.010000, 234.43s
# 2024-07-21 06:46:16,497 - INFO - epoch complete!
# 2024-07-21 06:46:16,497 - INFO - evaluating now!
# 2024-07-21 06:46:25,615 - INFO - Epoch [5/100] train_loss: 2.5117, val_loss: 2.6919, lr: 0.010000, 232.31s
# 2024-07-21 06:46:25,655 - INFO - Saved model at 5
# 2024-07-21 06:46:25,656 - INFO - Val loss decrease from 2.7772 to 2.6919, saving to ./libcity/cache/56551/model_cache/HierAttnLstm_PEMS_BAY_epoch5.tar
# 2024-07-21 06:50:09,796 - INFO - epoch complete!
# 2024-07-21 06:50:09,796 - INFO - evaluating now!
# 2024-07-21 06:50:19,109 - INFO - Epoch [6/100] train_loss: 2.4527, val_loss: 2.5899, lr: 0.010000, 233.45s
# 2024-07-21 06:50:19,152 - INFO - Saved model at 6
# 2024-07-21 06:50:19,152 - INFO - Val loss decrease from 2.6919 to 2.5899, saving to ./libcity/cache/56551/model_cache/HierAttnLstm_PEMS_BAY_epoch6.tar
# 2024-07-21 06:54:03,177 - INFO - epoch complete!
# 2024-07-21 06:54:03,178 - INFO - evaluating now!
# 2024-07-21 06:54:12,418 - INFO - Epoch [7/100] train_loss: 2.4210, val_loss: 2.6609, lr: 0.010000, 233.27s
# 2024-07-21 06:57:55,999 - INFO - epoch complete!
# 2024-07-21 06:57:56,000 - INFO - evaluating now!
# 2024-07-21 06:58:05,165 - INFO - Epoch [8/100] train_loss: 2.3944, val_loss: 3.0141, lr: 0.010000, 232.75s
# 2024-07-21 07:01:47,875 - INFO - epoch complete!
# 2024-07-21 07:01:47,875 - INFO - evaluating now!
# 2024-07-21 07:01:57,031 - INFO - Epoch [9/100] train_loss: 2.3736, val_loss: 2.6000, lr: 0.010000, 231.87s
# 2024-07-21 07:05:41,028 - INFO - epoch complete!
# 2024-07-21 07:05:41,028 - INFO - evaluating now!
# 2024-07-21 07:05:50,247 - INFO - Epoch [10/100] train_loss: 2.3623, val_loss: 2.6988, lr: 0.010000, 233.22s
# 2024-07-21 07:09:33,474 - INFO - epoch complete!
# 2024-07-21 07:09:33,474 - INFO - evaluating now!
# 2024-07-21 07:09:42,674 - INFO - Epoch [11/100] train_loss: 2.3431, val_loss: 2.5404, lr: 0.010000, 232.43s
# 2024-07-21 07:09:42,725 - INFO - Saved model at 11
# 2024-07-21 07:09:42,725 - INFO - Val loss decrease from 2.5899 to 2.5404, saving to ./libcity/cache/56551/model_cache/HierAttnLstm_PEMS_BAY_epoch11.tar
# 2024-07-21 07:13:26,776 - INFO - epoch complete!
# 2024-07-21 07:13:26,777 - INFO - evaluating now!
# 2024-07-21 07:13:35,968 - INFO - Epoch [12/100] train_loss: 2.4486, val_loss: 3.4808, lr: 0.010000, 233.24s
# 2024-07-21 07:17:22,654 - INFO - epoch complete!
# 2024-07-21 07:17:22,655 - INFO - evaluating now!
# 2024-07-21 07:17:31,814 - INFO - Epoch [13/100] train_loss: 2.9636, val_loss: 2.9547, lr: 0.010000, 235.85s
# 2024-07-21 07:21:16,213 - INFO - epoch complete!
# 2024-07-21 07:21:16,213 - INFO - evaluating now!
# 2024-07-21 07:21:25,335 - INFO - Epoch [14/100] train_loss: 2.6509, val_loss: 2.9011, lr: 0.010000, 233.52s
# 2024-07-21 07:25:10,513 - INFO - epoch complete!
# 2024-07-21 07:25:10,513 - INFO - evaluating now!
# 2024-07-21 07:25:19,709 - INFO - Epoch [15/100] train_loss: 2.5707, val_loss: 2.8238, lr: 0.010000, 234.37s
# 2024-07-21 07:29:03,915 - INFO - epoch complete!
# 2024-07-21 07:29:03,916 - INFO - evaluating now!
# 2024-07-21 07:29:13,185 - INFO - Epoch [16/100] train_loss: 2.5343, val_loss: 2.7101, lr: 0.010000, 233.48s
# 2024-07-21 07:32:58,269 - INFO - epoch complete!
# 2024-07-21 07:32:58,270 - INFO - evaluating now!
# 2024-07-21 07:33:07,505 - INFO - Epoch [17/100] train_loss: 2.5028, val_loss: 2.7370, lr: 0.010000, 234.32s
# 2024-07-21 07:36:52,369 - INFO - epoch complete!
# 2024-07-21 07:36:52,369 - INFO - evaluating now!
# 2024-07-21 07:37:01,539 - INFO - Epoch [18/100] train_loss: 2.4930, val_loss: 2.6333, lr: 0.010000, 234.03s
# 2024-07-21 07:40:46,413 - INFO - epoch complete!
# 2024-07-21 07:40:46,414 - INFO - evaluating now!
# 2024-07-21 07:40:55,670 - INFO - Epoch [19/100] train_loss: 2.4892, val_loss: 2.7548, lr: 0.010000, 234.13s
# 2024-07-21 07:44:40,308 - INFO - epoch complete!
# 2024-07-21 07:44:40,309 - INFO - evaluating now!
# 2024-07-21 07:44:49,538 - INFO - Epoch [20/100] train_loss: 2.4949, val_loss: 2.7344, lr: 0.010000, 233.87s
# 2024-07-21 07:48:33,540 - INFO - epoch complete!
# 2024-07-21 07:48:33,541 - INFO - evaluating now!
# 2024-07-21 07:48:42,825 - INFO - Epoch [21/100] train_loss: 2.4817, val_loss: 2.6213, lr: 0.010000, 233.29s
# 2024-07-21 07:48:42,825 - WARNING - Early stopping at epoch: 21
# 2024-07-21 07:48:42,825 - INFO - Trained totally 22 epochs, average train time is 224.472s, average eval time is 9.204s
# 2024-07-21 07:48:42,846 - INFO - Loaded model at 11
# 2024-07-21 07:48:42,847 - INFO - Saved model at ./libcity/cache/56551/model_cache/HierAttnLstm_PEMS_BAY.m
# 2024-07-21 07:48:42,884 - INFO - Start evaluating ...
# 2024-07-21 07:49:09,733 - INFO - Note that you select the single mode to evaluate!
# 2024-07-21 07:49:09,740 - INFO - Evaluate result is saved at ./libcity/cache/56551/evaluate_cache/2024_07_21_07_49_09_HierAttnLstm_PEMS_BAY.csv
# 2024-07-21 07:49:09,754 - INFO -
#         MAE  MAPE        MSE      RMSE  ...  masked_MSE  masked_RMSE        R2      EVAR
# 1  2.535659   inf  26.228603  5.121387  ...   25.944078     5.093533  0.718804  0.720353
# 2  2.535555   inf  26.227243  5.121254  ...   25.942720     5.093400  0.718814  0.720362
# 3  2.552284   inf  26.663197  5.163642  ...   26.378595     5.136010  0.714137  0.715766
# 4  2.563857   inf  26.959612  5.192265  ...   26.674986     5.164783  0.710957  0.712707
# 5  2.586244   inf  27.542858  5.248129  ...   27.258226     5.220941  0.704701  0.706637
# 6  2.609010   inf  28.136742  5.304408  ...   27.852116     5.277510  0.698330  0.700481
#
# [6 rows x 10 columns]

# %%
# !python run_model.py --task traffic_state_pred --model HierAttnLstm --dataset PEMS_BAY --config_file HierAttnLstm_128_3_2
# Out:
# 2024-07-21 07:49:14,186 - INFO - Log directory: ./libcity/log
# 2024-07-21 07:49:14,187 - INFO - Begin pipeline, task=traffic_state_pred, model_name=HierAttnLstm, dataset_name=PEMS_BAY, exp_id=43072
# 2024-07-21 07:49:14,187 - INFO - {'task': 'traffic_state_pred', 'model': 'HierAttnLstm', 'dataset': 'PEMS_BAY', 'saved_model': True, 'train': True, 'seed': 0, 'input_window': 48, 'output_window': 6, 'device': device(type='cuda', index=0), 'hidden_size': 128, 'num_layers': 3, 'dropout': 0.1, 'natt_hops': 2, 'nfc': 512, 'max_up_len': 80, 'dataset_class': 'TrafficStatePointDataset', 'executor': 'TrafficStateExecutor', 'evaluator': 'TrafficStateEvaluator', 'batch_size': 32, 'cache_dataset': True, 'num_workers': 0, 'pad_with_last_sample': True, 'train_rate': 0.7, 'eval_rate': 0.1, 'scaler': 'minmax01', 'load_external': False, 'normal_external': False, 'ext_scaler': 'none', 'add_time_in_day': False, 'add_day_in_week': False, 'robustness_test': False, 'noise_type': 'gaussian', 'disturb_rate': 0.5, 'noise_mean': [5], 'noise_SD': [10], 'gpu': True, 'gpu_id': 0, 'max_epoch': 100, 'train_loss': 'none', 'epoch': 0, 'learner': 'adam', 'learning_rate': 0.01, 'weight_decay': 0, 'lr_epsilon': 1e-08, 'lr_beta1': 0.9, 'lr_beta2': 0.999, 'lr_alpha': 0.99, 'lr_momentum': 0, 'lr_decay': False, 'lr_scheduler': 'multisteplr', 'lr_decay_ratio': 0.1, 'steps': [5, 20, 40, 70], 'step_size': 10, 'lr_T_max': 30, 'lr_eta_min': 0, 'lr_patience': 10, 'lr_threshold': 0.0001, 'clip_grad_norm': False, 'max_grad_norm': 1.0, 'use_early_stop': True, 'patience': 10, 'log_level': 'INFO', 'log_every': 1, 'load_best_epoch': True, 'hyper_tune': False, 'metrics': ['MAE', 'MAPE', 'MSE', 'RMSE', 'masked_MAE', 'masked_MAPE', 'masked_MSE', 'masked_RMSE', 'R2', 'EVAR'], 'evaluator_mode': 'single', 'save_mode': ['csv'], 'geo': {'including_types': ['Point'], 'Point': {}}, 'rel': {'including_types': ['geo'], 'geo': {'cost': 'num'}}, 'dyna': {'including_types': ['state'], 'state': {'entity_id': 'geo_id', 'traffic_speed': 'num'}}, 'data_col': ['traffic_speed'], 'weight_col': 'cost', 'data_files': ['PEMS_BAY'], 'geo_file': 'PEMS_BAY', 'rel_file': 'PEMS_BAY', 'output_dim': 1, 'time_intervals': 300, 'init_weight_inf_or_zero': 'inf', 'set_weight_link_or_dist': 'dist', 'calculate_weight_adj': True, 'weight_adj_epsilon': 0.1, 'exp_id': 43072}
# self.scaler_type  minmax01
# 2024-07-21 07:49:14,220 - INFO - Loaded file PEMS_BAY.geo, num_nodes=325
# 2024-07-21 07:49:14,229 - INFO - set_weight_link_or_dist: dist
# 2024-07-21 07:49:14,230 - INFO - init_weight_inf_or_zero: inf
# 2024-07-21 07:49:14,244 - INFO - Loaded file PEMS_BAY.rel, shape=(325, 325)
# 2024-07-21 07:49:14,244 - INFO - Start Calculate the weight by Gauss kernel!
# 2024-07-21 07:49:14,247 - INFO - Loading ./libcity/cache/dataset_cache/point_based_PEMS_BAY_48_6_0.7_0.1_minmax01_32_False_False_False_True.npz
# 2024-07-21 07:49:43,661 - INFO - train	x: (36444, 48, 325, 1), y: (36444, 6, 325, 1)
# 2024-07-21 07:49:43,662 - INFO - eval	x: (5206, 48, 325, 1), y: (5206, 6, 325, 1)
# 2024-07-21 07:49:43,662 - INFO - test	x: (10413, 48, 325, 1), y: (10413, 6, 325, 1)
# 2024-07-21 07:49:44,492 - INFO - MinMax01Scaler max: 85.1, min: 0.0
# 2024-07-21 07:49:44,493 - INFO - NoneScaler
# 2024-07-21 07:49:50.276014: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-07-21 07:49:50.327129: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-21 07:49:50.327176: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-21 07:49:50.328657: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-21 07:49:50.336237: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-21 07:49:51.543343: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-07-21 07:49:52,773 - INFO - HierAttnLstm(
#   (lstm_cells): ModuleList(
#     (0): LSTMCell(325, 128)
#     (1-2): 2 x LSTMCell(128, 128)
#   )
#   (hidden_state_pooling): ModuleList(
#     (0-1): 2 x SelfAttentionPooling(
#       (W): Linear(in_features=128, out_features=1, bias=True)
#     )
#   )
#   (cell_state_pooling): ModuleList(
#     (0-1): 2 x SelfAttentionPooling(
#       (W): Linear(in_features=128, out_features=1, bias=True)
#     )
#   )
#   (self_attention): SelfAttention(
#     (ut_dense): Sequential(
#       (0): Linear(in_features=128, out_features=128, bias=True)
#       (1): Tanh()
#     )
#     (et_dense): Linear(in_features=128, out_features=2, bias=True)
#     (softmax): Softmax(dim=-1)
#   )
#   (fc_layer): Sequential(
#     (0): Linear(in_features=256, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=325, bias=True)
#   )
# )
# 2024-07-21 07:49:52,774 - INFO - lstm_cells.0.weight_ih	torch.Size([512, 325])	cuda:0	True
# 2024-07-21 07:49:52,774 - INFO - lstm_cells.0.weight_hh	torch.Size([512, 128])	cuda:0	True
# 2024-07-21 07:49:52,774 - INFO - lstm_cells.0.bias_ih	torch.Size([512])	cuda:0	True
# 2024-07-21 07:49:52,775 - INFO - lstm_cells.0.bias_hh	torch.Size([512])	cuda:0	True
# 2024-07-21 07:49:52,775 - INFO - lstm_cells.1.weight_ih	torch.Size([512, 128])	cuda:0	True
# 2024-07-21 07:49:52,775 - INFO - lstm_cells.1.weight_hh	torch.Size([512, 128])	cuda:0	True
# 2024-07-21 07:49:52,775 - INFO - lstm_cells.1.bias_ih	torch.Size([512])	cuda:0	True
# 2024-07-21 07:49:52,775 - INFO - lstm_cells.1.bias_hh	torch.Size([512])	cuda:0	True
# 2024-07-21 07:49:52,775 - INFO - lstm_cells.2.weight_ih	torch.Size([512, 128])	cuda:0	True
# 2024-07-21 07:49:52,775 - INFO - lstm_cells.2.weight_hh	torch.Size([512, 128])	cuda:0	True
# 2024-07-21 07:49:52,775 - INFO - lstm_cells.2.bias_ih	torch.Size([512])	cuda:0	True
# 2024-07-21 07:49:52,775 - INFO - lstm_cells.2.bias_hh	torch.Size([512])	cuda:0	True
# 2024-07-21 07:49:52,775 - INFO - hidden_state_pooling.0.W.weight	torch.Size([1, 128])	cuda:0	True
# 2024-07-21 07:49:52,775 - INFO - hidden_state_pooling.0.W.bias	torch.Size([1])	cuda:0	True
# 2024-07-21 07:49:52,776 - INFO - hidden_state_pooling.1.W.weight	torch.Size([1, 128])	cuda:0	True
# 2024-07-21 07:49:52,776 - INFO - hidden_state_pooling.1.W.bias	torch.Size([1])	cuda:0	True
# 2024-07-21 07:49:52,776 - INFO - cell_state_pooling.0.W.weight	torch.Size([1, 128])	cuda:0	True
# 2024-07-21 07:49:52,776 - INFO - cell_state_pooling.0.W.bias	torch.Size([1])	cuda:0	True
# 2024-07-21 07:49:52,776 - INFO - cell_state_pooling.1.W.weight	torch.Size([1, 128])	cuda:0	True
# 2024-07-21 07:49:52,776 - INFO - cell_state_pooling.1.W.bias	torch.Size([1])	cuda:0	True
# 2024-07-21 07:49:52,776 - INFO - self_attention.ut_dense.0.weight	torch.Size([128, 128])	cuda:0	True
# 2024-07-21 07:49:52,776 - INFO - self_attention.ut_dense.0.bias	torch.Size([128])	cuda:0	True
# 2024-07-21 07:49:52,776 - INFO - self_attention.et_dense.weight	torch.Size([2, 128])	cuda:0	True
# 2024-07-21 07:49:52,776 - INFO - self_attention.et_dense.bias	torch.Size([2])	cuda:0	True
# 2024-07-21 07:49:52,777 - INFO - fc_layer.0.weight	torch.Size([512, 256])	cuda:0	True
# 2024-07-21 07:49:52,777 - INFO - fc_layer.0.bias	torch.Size([512])	cuda:0	True
# 2024-07-21 07:49:52,777 - INFO - fc_layer.2.weight	torch.Size([325, 512])	cuda:0	True
# 2024-07-21 07:49:52,777 - INFO - fc_layer.2.bias	torch.Size([325])	cuda:0	True
# 2024-07-21 07:49:52,777 - INFO - Total parameter numbers: 812747
# 2024-07-21 07:49:52,777 - INFO - You select `adam` optimizer.
# 2024-07-21 07:49:52,778 - WARNING - Received none train loss func and will use the loss func defined in the model.
# 2024-07-21 07:49:52,778 - INFO - Start training ...
# 2024-07-21 07:49:52,778 - INFO - num_batches:1139
# 2024-07-21 07:54:26,586 - INFO - epoch complete!
# 2024-07-21 07:54:26,586 - INFO - evaluating now!
# 2024-07-21 07:54:37,810 - INFO - Epoch [0/100] train_loss: 5.0105, val_loss: 3.4767, lr: 0.010000, 285.03s
# 2024-07-21 07:54:37,852 - INFO - Saved model at 0
# 2024-07-21 07:54:37,852 - INFO - Val loss decrease from inf to 3.4767, saving to ./libcity/cache/43072/model_cache/HierAttnLstm_PEMS_BAY_epoch0.tar
# 2024-07-21 07:59:12,104 - INFO - epoch complete!
# 2024-07-21 07:59:12,105 - INFO - evaluating now!
# 2024-07-21 07:59:23,389 - INFO - Epoch [1/100] train_loss: 2.8145, val_loss: 3.1463, lr: 0.010000, 285.54s
# 2024-07-21 07:59:23,432 - INFO - Saved model at 1
# 2024-07-21 07:59:23,432 - INFO - Val loss decrease from 3.4767 to 3.1463, saving to ./libcity/cache/43072/model_cache/HierAttnLstm_PEMS_BAY_epoch1.tar
# 2024-07-21 08:03:57,880 - INFO - epoch complete!
# 2024-07-21 08:03:57,880 - INFO - evaluating now!
# 2024-07-21 08:04:09,251 - INFO - Epoch [2/100] train_loss: 2.5195, val_loss: 2.7766, lr: 0.010000, 285.82s
# 2024-07-21 08:04:09,295 - INFO - Saved model at 2
# 2024-07-21 08:04:09,296 - INFO - Val loss decrease from 3.1463 to 2.7766, saving to ./libcity/cache/43072/model_cache/HierAttnLstm_PEMS_BAY_epoch2.tar
# 2024-07-21 08:08:43,997 - INFO - epoch complete!
# 2024-07-21 08:08:43,997 - INFO - evaluating now!
# 2024-07-21 08:08:55,247 - INFO - Epoch [3/100] train_loss: 2.4209, val_loss: 2.5966, lr: 0.010000, 285.95s
# 2024-07-21 08:08:55,294 - INFO - Saved model at 3
# 2024-07-21 08:08:55,294 - INFO - Val loss decrease from 2.7766 to 2.5966, saving to ./libcity/cache/43072/model_cache/HierAttnLstm_PEMS_BAY_epoch3.tar
# 2024-07-21 08:13:29,586 - INFO - epoch complete!
# 2024-07-21 08:13:29,586 - INFO - evaluating now!
# 2024-07-21 08:13:40,958 - INFO - Epoch [4/100] train_loss: 2.3754, val_loss: 2.5399, lr: 0.010000, 285.66s
# 2024-07-21 08:13:41,002 - INFO - Saved model at 4
# 2024-07-21 08:13:41,002 - INFO - Val loss decrease from 2.5966 to 2.5399, saving to ./libcity/cache/43072/model_cache/HierAttnLstm_PEMS_BAY_epoch4.tar
# 2024-07-21 08:18:16,366 - INFO - epoch complete!
# 2024-07-21 08:18:16,366 - INFO - evaluating now!
# 2024-07-21 08:18:27,741 - INFO - Epoch [5/100] train_loss: 2.3348, val_loss: 2.5943, lr: 0.010000, 286.74s
# 2024-07-21 08:23:02,492 - INFO - epoch complete!
# 2024-07-21 08:23:02,493 - INFO - evaluating now!
# 2024-07-21 08:23:13,745 - INFO - Epoch [6/100] train_loss: 2.3115, val_loss: 2.5049, lr: 0.010000, 286.00s
# 2024-07-21 08:23:13,789 - INFO - Saved model at 6
# 2024-07-21 08:23:13,790 - INFO - Val loss decrease from 2.5399 to 2.5049, saving to ./libcity/cache/43072/model_cache/HierAttnLstm_PEMS_BAY_epoch6.tar
# 2024-07-21 08:27:48,604 - INFO - epoch complete!
# 2024-07-21 08:27:48,604 - INFO - evaluating now!
# 2024-07-21 08:27:59,865 - INFO - Epoch [7/100] train_loss: 2.2882, val_loss: 2.4794, lr: 0.010000, 286.07s
# 2024-07-21 08:27:59,909 - INFO - Saved model at 7
# 2024-07-21 08:27:59,910 - INFO - Val loss decrease from 2.5049 to 2.4794, saving to ./libcity/cache/43072/model_cache/HierAttnLstm_PEMS_BAY_epoch7.tar
# 2024-07-21 08:32:34,113 - INFO - epoch complete!
# 2024-07-21 08:32:34,113 - INFO - evaluating now!
# 2024-07-21 08:32:45,434 - INFO - Epoch [8/100] train_loss: 2.2733, val_loss: 2.5343, lr: 0.010000, 285.52s
# 2024-07-21 08:37:21,714 - INFO - epoch complete!
# 2024-07-21 08:37:21,714 - INFO - evaluating now!
# 2024-07-21 08:37:33,012 - INFO - Epoch [9/100] train_loss: 2.2528, val_loss: 2.5138, lr: 0.010000, 287.58s
# 2024-07-21 08:42:07,924 - INFO - epoch complete!
# 2024-07-21 08:42:07,925 - INFO - evaluating now!
# 2024-07-21 08:42:19,327 - INFO - Epoch [10/100] train_loss: 2.2317, val_loss: 2.5172, lr: 0.010000, 286.31s
# 2024-07-21 08:46:55,122 - INFO - epoch complete!
# 2024-07-21 08:46:55,122 - INFO - evaluating now!
# 2024-07-21 08:47:06,491 - INFO - Epoch [11/100] train_loss: 2.2298, val_loss: 2.4673, lr: 0.010000, 287.16s
# 2024-07-21 08:47:06,542 - INFO - Saved model at 11
# 2024-07-21 08:47:06,542 - INFO - Val loss decrease from 2.4794 to 2.4673, saving to ./libcity/cache/43072/model_cache/HierAttnLstm_PEMS_BAY_epoch11.tar
# 2024-07-21 08:51:40,665 - INFO - epoch complete!
# 2024-07-21 08:51:40,666 - INFO - evaluating now!
# 2024-07-21 08:51:51,936 - INFO - Epoch [12/100] train_loss: 2.2193, val_loss: 2.5019, lr: 0.010000, 285.39s
# 2024-07-21 08:56:26,212 - INFO - epoch complete!
# 2024-07-21 08:56:26,212 - INFO - evaluating now!
# 2024-07-21 08:56:37,485 - INFO - Epoch [13/100] train_loss: 2.2124, val_loss: 2.4740, lr: 0.010000, 285.55s
# 2024-07-21 09:01:11,267 - INFO - epoch complete!
# 2024-07-21 09:01:11,268 - INFO - evaluating now!
# 2024-07-21 09:01:22,547 - INFO - Epoch [14/100] train_loss: 2.2023, val_loss: 2.5217, lr: 0.010000, 285.06s
# 2024-07-21 09:05:55,487 - INFO - epoch complete!
# 2024-07-21 09:05:55,488 - INFO - evaluating now!
# 2024-07-21 09:06:06,857 - INFO - Epoch [15/100] train_loss: 2.2008, val_loss: 2.4853, lr: 0.010000, 284.31s
# 2024-07-21 09:10:39,494 - INFO - epoch complete!
# 2024-07-21 09:10:39,495 - INFO - evaluating now!
# 2024-07-21 09:10:50,786 - INFO - Epoch [16/100] train_loss: 2.1926, val_loss: 2.4226, lr: 0.010000, 283.93s
# 2024-07-21 09:10:50,831 - INFO - Saved model at 16
# 2024-07-21 09:10:50,832 - INFO - Val loss decrease from 2.4673 to 2.4226, saving to ./libcity/cache/43072/model_cache/HierAttnLstm_PEMS_BAY_epoch16.tar
# 2024-07-21 09:15:23,997 - INFO - epoch complete!
# 2024-07-21 09:15:23,998 - INFO - evaluating now!
# 2024-07-21 09:15:35,257 - INFO - Epoch [17/100] train_loss: 2.1820, val_loss: 2.4893, lr: 0.010000, 284.42s
# 2024-07-21 09:20:10,111 - INFO - epoch complete!
# 2024-07-21 09:20:10,111 - INFO - evaluating now!
# 2024-07-21 09:20:21,429 - INFO - Epoch [18/100] train_loss: 2.1880, val_loss: 2.5035, lr: 0.010000, 286.17s
# 2024-07-21 09:24:56,945 - INFO - epoch complete!
# 2024-07-21 09:24:56,946 - INFO - evaluating now!
# 2024-07-21 09:25:08,170 - INFO - Epoch [19/100] train_loss: 2.1758, val_loss: 2.4485, lr: 0.010000, 286.74s
# 2024-07-21 09:29:41,567 - INFO - epoch complete!
# 2024-07-21 09:29:41,568 - INFO - evaluating now!
# 2024-07-21 09:29:52,941 - INFO - Epoch [20/100] train_loss: 2.1753, val_loss: 2.4269, lr: 0.010000, 284.77s
# 2024-07-21 09:34:27,080 - INFO - epoch complete!
# 2024-07-21 09:34:27,081 - INFO - evaluating now!
# 2024-07-21 09:34:38,379 - INFO - Epoch [21/100] train_loss: 2.1664, val_loss: 2.4403, lr: 0.010000, 285.44s
# 2024-07-21 09:39:12,124 - INFO - epoch complete!
# 2024-07-21 09:39:12,125 - INFO - evaluating now!
# 2024-07-21 09:39:23,440 - INFO - Epoch [22/100] train_loss: 2.1612, val_loss: 2.4645, lr: 0.010000, 285.06s
# 2024-07-21 09:43:56,903 - INFO - epoch complete!
# 2024-07-21 09:43:56,904 - INFO - evaluating now!
# 2024-07-21 09:44:08,284 - INFO - Epoch [23/100] train_loss: 2.1629, val_loss: 2.4921, lr: 0.010000, 284.84s
# 2024-07-21 09:48:42,177 - INFO - epoch complete!
# 2024-07-21 09:48:42,178 - INFO - evaluating now!
# 2024-07-21 09:48:53,539 - INFO - Epoch [24/100] train_loss: 2.1488, val_loss: 2.4753, lr: 0.010000, 285.25s
# 2024-07-21 09:53:26,724 - INFO - epoch complete!
# 2024-07-21 09:53:26,724 - INFO - evaluating now!
# 2024-07-21 09:53:38,103 - INFO - Epoch [25/100] train_loss: 2.1529, val_loss: 2.4290, lr: 0.010000, 284.56s
# 2024-07-21 09:58:11,531 - INFO - epoch complete!
# 2024-07-21 09:58:11,532 - INFO - evaluating now!
# 2024-07-21 09:58:22,872 - INFO - Epoch [26/100] train_loss: 2.1466, val_loss: 2.4373, lr: 0.010000, 284.77s
# 2024-07-21 09:58:22,872 - WARNING - Early stopping at epoch: 26
# 2024-07-21 09:58:22,872 - INFO - Trained totally 27 epochs, average train time is 274.227s, average eval time is 11.315s
# 2024-07-21 09:58:22,895 - INFO - Loaded model at 16
# 2024-07-21 09:58:22,897 - INFO - Saved model at ./libcity/cache/43072/model_cache/HierAttnLstm_PEMS_BAY.m
# 2024-07-21 09:58:22,938 - INFO - Start evaluating ...
# 2024-07-21 09:58:50,548 - INFO - Note that you select the single mode to evaluate!
# 2024-07-21 09:58:50,577 - INFO - Evaluate result is saved at ./libcity/cache/43072/evaluate_cache/2024_07_21_09_58_50_HierAttnLstm_PEMS_BAY.csv
# 2024-07-21 09:58:50,590 - INFO -
#         MAE  MAPE        MSE      RMSE  ...  masked_MSE  masked_RMSE        R2      EVAR
# 1  2.469609   inf  26.028069  5.101771  ...   25.745779     5.074030  0.720954  0.725208
# 2  2.469511   inf  26.026773  5.101644  ...   25.744484     5.073902  0.720963  0.725216
# 3  2.469442   inf  26.025864  5.101555  ...   25.743580     5.073813  0.720970  0.725222
# 4  2.469399   inf  26.025139  5.101484  ...   25.742853     5.073741  0.720976  0.725228
# 5  2.469359   inf  26.024092  5.101381  ...   25.741804     5.073638  0.720984  0.725236
# 6  2.469301   inf  26.022905  5.101265  ...   25.740620     5.073522  0.720994  0.725246
#
# [6 rows x 10 columns]

# %%
# !python run_model.py --task traffic_state_pred --model HierAttnLstm --dataset PEMS_BAY --config_file HierAttnLstm_128_3_3
# Out:
# Traceback (most recent call last):
#   File "D:\Dropbox\0_Project_Ongoing\Big Data Application for Travel Time prediction\Bigscity-LibCity\run_model.py", line 12, in <module>
#     from libcity.pipeline import run_model
#   File "D:\Dropbox\0_Project_Ongoing\Big Data Application for Travel Time prediction\Bigscity-LibCity\libcity\pipeline\__init__.py", line 1, in <module>
#     from libcity.pipeline.pipeline import run_model, hyper_parameter, objective_function
#   File "D:\Dropbox\0_Project_Ongoing\Big Data Application for Travel Time prediction\Bigscity-LibCity\libcity\pipeline\pipeline.py", line 2, in <module>
#     from ray import tune
# ModuleNotFoundError: No module named 'ray'

# %%
# !python run_model.py --task traffic_state_pred --model HierAttnLstm --dataset PEMS_BAY --config_file HierAttnLstm_128_3_4
# Out:
# 2024-07-21 09:58:55,102 - INFO - Log directory: ./libcity/log
# 2024-07-21 09:58:55,103 - INFO - Begin pipeline, task=traffic_state_pred, model_name=HierAttnLstm, dataset_name=PEMS_BAY, exp_id=30355
# 2024-07-21 09:58:55,103 - INFO - {'task': 'traffic_state_pred', 'model': 'HierAttnLstm', 'dataset': 'PEMS_BAY', 'saved_model': True, 'train': True, 'seed': 0, 'input_window': 48, 'output_window': 6, 'device': device(type='cuda', index=0), 'hidden_size': 128, 'num_layers': 3, 'dropout': 0.1, 'natt_hops': 4, 'nfc': 512, 'max_up_len': 80, 'dataset_class': 'TrafficStatePointDataset', 'executor': 'TrafficStateExecutor', 'evaluator': 'TrafficStateEvaluator', 'batch_size': 32, 'cache_dataset': True, 'num_workers': 0, 'pad_with_last_sample': True, 'train_rate': 0.7, 'eval_rate': 0.1, 'scaler': 'minmax01', 'load_external': False, 'normal_external': False, 'ext_scaler': 'none', 'add_time_in_day': False, 'add_day_in_week': False, 'robustness_test': False, 'noise_type': 'gaussian', 'disturb_rate': 0.5, 'noise_mean': [5], 'noise_SD': [10], 'gpu': True, 'gpu_id': 0, 'max_epoch': 100, 'train_loss': 'none', 'epoch': 0, 'learner': 'adam', 'learning_rate': 0.01, 'weight_decay': 0, 'lr_epsilon': 1e-08, 'lr_beta1': 0.9, 'lr_beta2': 0.999, 'lr_alpha': 0.99, 'lr_momentum': 0, 'lr_decay': False, 'lr_scheduler': 'multisteplr', 'lr_decay_ratio': 0.1, 'steps': [5, 20, 40, 70], 'step_size': 10, 'lr_T_max': 30, 'lr_eta_min': 0, 'lr_patience': 10, 'lr_threshold': 0.0001, 'clip_grad_norm': False, 'max_grad_norm': 1.0, 'use_early_stop': True, 'patience': 10, 'log_level': 'INFO', 'log_every': 1, 'load_best_epoch': True, 'hyper_tune': False, 'metrics': ['MAE', 'MAPE', 'MSE', 'RMSE', 'masked_MAE', 'masked_MAPE', 'masked_MSE', 'masked_RMSE', 'R2', 'EVAR'], 'evaluator_mode': 'single', 'save_mode': ['csv'], 'geo': {'including_types': ['Point'], 'Point': {}}, 'rel': {'including_types': ['geo'], 'geo': {'cost': 'num'}}, 'dyna': {'including_types': ['state'], 'state': {'entity_id': 'geo_id', 'traffic_speed': 'num'}}, 'data_col': ['traffic_speed'], 'weight_col': 'cost', 'data_files': ['PEMS_BAY'], 'geo_file': 'PEMS_BAY', 'rel_file': 'PEMS_BAY', 'output_dim': 1, 'time_intervals': 300, 'init_weight_inf_or_zero': 'inf', 'set_weight_link_or_dist': 'dist', 'calculate_weight_adj': True, 'weight_adj_epsilon': 0.1, 'exp_id': 30355}
# self.scaler_type  minmax01
# 2024-07-21 09:58:55,135 - INFO - Loaded file PEMS_BAY.geo, num_nodes=325
# 2024-07-21 09:58:55,145 - INFO - set_weight_link_or_dist: dist
# 2024-07-21 09:58:55,146 - INFO - init_weight_inf_or_zero: inf
# 2024-07-21 09:58:55,161 - INFO - Loaded file PEMS_BAY.rel, shape=(325, 325)
# 2024-07-21 09:58:55,161 - INFO - Start Calculate the weight by Gauss kernel!
# 2024-07-21 09:58:55,164 - INFO - Loading ./libcity/cache/dataset_cache/point_based_PEMS_BAY_48_6_0.7_0.1_minmax01_32_False_False_False_True.npz
# 2024-07-21 09:59:24,699 - INFO - train	x: (36444, 48, 325, 1), y: (36444, 6, 325, 1)
# 2024-07-21 09:59:24,700 - INFO - eval	x: (5206, 48, 325, 1), y: (5206, 6, 325, 1)
# 2024-07-21 09:59:24,700 - INFO - test	x: (10413, 48, 325, 1), y: (10413, 6, 325, 1)
# 2024-07-21 09:59:25,531 - INFO - MinMax01Scaler max: 85.1, min: 0.0
# 2024-07-21 09:59:25,531 - INFO - NoneScaler
# 2024-07-21 09:59:31.293496: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-07-21 09:59:31.343600: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-21 09:59:31.343645: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-21 09:59:31.345009: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-21 09:59:31.352650: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-21 09:59:32.566587: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-07-21 09:59:33,830 - INFO - HierAttnLstm(
#   (lstm_cells): ModuleList(
#     (0): LSTMCell(325, 128)
#     (1-2): 2 x LSTMCell(128, 128)
#   )
#   (hidden_state_pooling): ModuleList(
#     (0-1): 2 x SelfAttentionPooling(
#       (W): Linear(in_features=128, out_features=1, bias=True)
#     )
#   )
#   (cell_state_pooling): ModuleList(
#     (0-1): 2 x SelfAttentionPooling(
#       (W): Linear(in_features=128, out_features=1, bias=True)
#     )
#   )
#   (self_attention): SelfAttention(
#     (ut_dense): Sequential(
#       (0): Linear(in_features=128, out_features=128, bias=True)
#       (1): Tanh()
#     )
#     (et_dense): Linear(in_features=128, out_features=4, bias=True)
#     (softmax): Softmax(dim=-1)
#   )
#   (fc_layer): Sequential(
#     (0): Linear(in_features=512, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=325, bias=True)
#   )
# )
# 2024-07-21 09:59:33,831 - INFO - lstm_cells.0.weight_ih	torch.Size([512, 325])	cuda:0	True
# 2024-07-21 09:59:33,831 - INFO - lstm_cells.0.weight_hh	torch.Size([512, 128])	cuda:0	True
# 2024-07-21 09:59:33,831 - INFO - lstm_cells.0.bias_ih	torch.Size([512])	cuda:0	True
# 2024-07-21 09:59:33,831 - INFO - lstm_cells.0.bias_hh	torch.Size([512])	cuda:0	True
# 2024-07-21 09:59:33,831 - INFO - lstm_cells.1.weight_ih	torch.Size([512, 128])	cuda:0	True
# 2024-07-21 09:59:33,831 - INFO - lstm_cells.1.weight_hh	torch.Size([512, 128])	cuda:0	True
# 2024-07-21 09:59:33,832 - INFO - lstm_cells.1.bias_ih	torch.Size([512])	cuda:0	True
# 2024-07-21 09:59:33,832 - INFO - lstm_cells.1.bias_hh	torch.Size([512])	cuda:0	True
# 2024-07-21 09:59:33,832 - INFO - lstm_cells.2.weight_ih	torch.Size([512, 128])	cuda:0	True
# 2024-07-21 09:59:33,832 - INFO - lstm_cells.2.weight_hh	torch.Size([512, 128])	cuda:0	True
# 2024-07-21 09:59:33,832 - INFO - lstm_cells.2.bias_ih	torch.Size([512])	cuda:0	True
# 2024-07-21 09:59:33,832 - INFO - lstm_cells.2.bias_hh	torch.Size([512])	cuda:0	True
# 2024-07-21 09:59:33,832 - INFO - hidden_state_pooling.0.W.weight	torch.Size([1, 128])	cuda:0	True
# 2024-07-21 09:59:33,832 - INFO - hidden_state_pooling.0.W.bias	torch.Size([1])	cuda:0	True
# 2024-07-21 09:59:33,832 - INFO - hidden_state_pooling.1.W.weight	torch.Size([1, 128])	cuda:0	True
# 2024-07-21 09:59:33,833 - INFO - hidden_state_pooling.1.W.bias	torch.Size([1])	cuda:0	True
# 2024-07-21 09:59:33,833 - INFO - cell_state_pooling.0.W.weight	torch.Size([1, 128])	cuda:0	True
# 2024-07-21 09:59:33,833 - INFO - cell_state_pooling.0.W.bias	torch.Size([1])	cuda:0	True
# 2024-07-21 09:59:33,833 - INFO - cell_state_pooling.1.W.weight	torch.Size([1, 128])	cuda:0	True
# 2024-07-21 09:59:33,833 - INFO - cell_state_pooling.1.W.bias	torch.Size([1])	cuda:0	True
# 2024-07-21 09:59:33,833 - INFO - self_attention.ut_dense.0.weight	torch.Size([128, 128])	cuda:0	True
# 2024-07-21 09:59:33,833 - INFO - self_attention.ut_dense.0.bias	torch.Size([128])	cuda:0	True
# 2024-07-21 09:59:33,833 - INFO - self_attention.et_dense.weight	torch.Size([4, 128])	cuda:0	True
# 2024-07-21 09:59:33,833 - INFO - self_attention.et_dense.bias	torch.Size([4])	cuda:0	True
# 2024-07-21 09:59:33,834 - INFO - fc_layer.0.weight	torch.Size([512, 512])	cuda:0	True
# 2024-07-21 09:59:33,834 - INFO - fc_layer.0.bias	torch.Size([512])	cuda:0	True
# 2024-07-21 09:59:33,834 - INFO - fc_layer.2.weight	torch.Size([325, 512])	cuda:0	True
# 2024-07-21 09:59:33,834 - INFO - fc_layer.2.bias	torch.Size([325])	cuda:0	True
# 2024-07-21 09:59:33,834 - INFO - Total parameter numbers: 944077
# 2024-07-21 09:59:33,834 - INFO - You select `adam` optimizer.
# 2024-07-21 09:59:33,835 - WARNING - Received none train loss func and will use the loss func defined in the model.
# 2024-07-21 09:59:33,835 - INFO - Start training ...
# 2024-07-21 09:59:33,835 - INFO - num_batches:1139
# 2024-07-21 10:04:08,388 - INFO - epoch complete!
# 2024-07-21 10:04:08,388 - INFO - evaluating now!
# 2024-07-21 10:04:19,639 - INFO - Epoch [0/100] train_loss: 5.0793, val_loss: 4.5207, lr: 0.010000, 285.80s
# 2024-07-21 10:04:19,686 - INFO - Saved model at 0
# 2024-07-21 10:04:19,686 - INFO - Val loss decrease from inf to 4.5207, saving to ./libcity/cache/30355/model_cache/HierAttnLstm_PEMS_BAY_epoch0.tar
# 2024-07-21 10:08:53,111 - INFO - epoch complete!
# 2024-07-21 10:08:53,112 - INFO - evaluating now!
# 2024-07-21 10:09:04,327 - INFO - Epoch [1/100] train_loss: 3.3832, val_loss: 3.0085, lr: 0.010000, 284.64s
# 2024-07-21 10:09:04,374 - INFO - Saved model at 1
# 2024-07-21 10:09:04,375 - INFO - Val loss decrease from 4.5207 to 3.0085, saving to ./libcity/cache/30355/model_cache/HierAttnLstm_PEMS_BAY_epoch1.tar
# 2024-07-21 10:13:39,426 - INFO - epoch complete!
# 2024-07-21 10:13:39,426 - INFO - evaluating now!
# 2024-07-21 10:13:50,702 - INFO - Epoch [2/100] train_loss: 2.6758, val_loss: 2.8637, lr: 0.010000, 286.33s
# 2024-07-21 10:13:50,747 - INFO - Saved model at 2
# 2024-07-21 10:13:50,748 - INFO - Val loss decrease from 3.0085 to 2.8637, saving to ./libcity/cache/30355/model_cache/HierAttnLstm_PEMS_BAY_epoch2.tar
# 2024-07-21 10:18:24,552 - INFO - epoch complete!
# 2024-07-21 10:18:24,552 - INFO - evaluating now!
# 2024-07-21 10:18:35,798 - INFO - Epoch [3/100] train_loss: 2.5460, val_loss: 2.7482, lr: 0.010000, 285.05s
# 2024-07-21 10:18:35,850 - INFO - Saved model at 3
# 2024-07-21 10:18:35,850 - INFO - Val loss decrease from 2.8637 to 2.7482, saving to ./libcity/cache/30355/model_cache/HierAttnLstm_PEMS_BAY_epoch3.tar
# 2024-07-21 10:23:09,247 - INFO - epoch complete!
# 2024-07-21 10:23:09,248 - INFO - evaluating now!
# 2024-07-21 10:23:20,645 - INFO - Epoch [4/100] train_loss: 2.4746, val_loss: 2.6563, lr: 0.010000, 284.79s
# 2024-07-21 10:23:20,694 - INFO - Saved model at 4
# 2024-07-21 10:23:20,694 - INFO - Val loss decrease from 2.7482 to 2.6563, saving to ./libcity/cache/30355/model_cache/HierAttnLstm_PEMS_BAY_epoch4.tar
# 2024-07-21 10:27:55,575 - INFO - epoch complete!
# 2024-07-21 10:27:55,576 - INFO - evaluating now!
# 2024-07-21 10:28:07,055 - INFO - Epoch [5/100] train_loss: 2.4340, val_loss: 2.6263, lr: 0.010000, 286.36s
# 2024-07-21 10:28:07,104 - INFO - Saved model at 5
# 2024-07-21 10:28:07,104 - INFO - Val loss decrease from 2.6563 to 2.6263, saving to ./libcity/cache/30355/model_cache/HierAttnLstm_PEMS_BAY_epoch5.tar
# 2024-07-21 10:32:40,346 - INFO - epoch complete!
# 2024-07-21 10:32:40,346 - INFO - evaluating now!
# 2024-07-21 10:32:51,615 - INFO - Epoch [6/100] train_loss: 2.3918, val_loss: 2.6955, lr: 0.010000, 284.51s
# 2024-07-21 10:37:26,300 - INFO - epoch complete!
# 2024-07-21 10:37:26,300 - INFO - evaluating now!
# 2024-07-21 10:37:37,581 - INFO - Epoch [7/100] train_loss: 2.3736, val_loss: 2.6068, lr: 0.010000, 285.97s
# 2024-07-21 10:37:37,628 - INFO - Saved model at 7
# 2024-07-21 10:37:37,629 - INFO - Val loss decrease from 2.6263 to 2.6068, saving to ./libcity/cache/30355/model_cache/HierAttnLstm_PEMS_BAY_epoch7.tar
# 2024-07-21 10:42:12,876 - INFO - epoch complete!
# 2024-07-21 10:42:12,877 - INFO - evaluating now!
# 2024-07-21 10:42:24,193 - INFO - Epoch [8/100] train_loss: 2.3356, val_loss: 2.6010, lr: 0.010000, 286.56s
# 2024-07-21 10:42:24,240 - INFO - Saved model at 8
# 2024-07-21 10:42:24,240 - INFO - Val loss decrease from 2.6068 to 2.6010, saving to ./libcity/cache/30355/model_cache/HierAttnLstm_PEMS_BAY_epoch8.tar
# 2024-07-21 10:46:57,005 - INFO - epoch complete!
# 2024-07-21 10:46:57,005 - INFO - evaluating now!
# 2024-07-21 10:47:08,224 - INFO - Epoch [9/100] train_loss: 2.3248, val_loss: 2.5245, lr: 0.010000, 283.98s
# 2024-07-21 10:47:08,272 - INFO - Saved model at 9
# 2024-07-21 10:47:08,273 - INFO - Val loss decrease from 2.6010 to 2.5245, saving to ./libcity/cache/30355/model_cache/HierAttnLstm_PEMS_BAY_epoch9.tar
# 2024-07-21 10:51:39,969 - INFO - epoch complete!
# 2024-07-21 10:51:39,970 - INFO - evaluating now!
# 2024-07-21 10:51:51,194 - INFO - Epoch [10/100] train_loss: 2.3164, val_loss: 2.6982, lr: 0.010000, 282.92s
# 2024-07-21 10:56:24,572 - INFO - epoch complete!
# 2024-07-21 10:56:24,573 - INFO - evaluating now!
# 2024-07-21 10:56:35,942 - INFO - Epoch [11/100] train_loss: 2.3074, val_loss: 2.5365, lr: 0.010000, 284.75s
# 2024-07-21 11:01:10,075 - INFO - epoch complete!
# 2024-07-21 11:01:10,076 - INFO - evaluating now!
# 2024-07-21 11:01:21,310 - INFO - Epoch [12/100] train_loss: 2.2931, val_loss: 2.6195, lr: 0.010000, 285.37s
# 2024-07-21 11:05:55,580 - INFO - epoch complete!
# 2024-07-21 11:05:55,581 - INFO - evaluating now!
# 2024-07-21 11:06:06,899 - INFO - Epoch [13/100] train_loss: 2.2902, val_loss: 2.5009, lr: 0.010000, 285.59s
# 2024-07-21 11:06:06,945 - INFO - Saved model at 13
# 2024-07-21 11:06:06,945 - INFO - Val loss decrease from 2.5245 to 2.5009, saving to ./libcity/cache/30355/model_cache/HierAttnLstm_PEMS_BAY_epoch13.tar
# 2024-07-21 11:10:40,463 - INFO - epoch complete!
# 2024-07-21 11:10:40,464 - INFO - evaluating now!
# 2024-07-21 11:10:51,770 - INFO - Epoch [14/100] train_loss: 2.2791, val_loss: 2.5253, lr: 0.010000, 284.82s
# 2024-07-21 11:15:25,853 - INFO - epoch complete!
# 2024-07-21 11:15:25,854 - INFO - evaluating now!
# 2024-07-21 11:15:37,194 - INFO - Epoch [15/100] train_loss: 2.2776, val_loss: 2.5046, lr: 0.010000, 285.42s
# 2024-07-21 11:20:12,385 - INFO - epoch complete!
# 2024-07-21 11:20:12,386 - INFO - evaluating now!
# 2024-07-21 11:20:23,661 - INFO - Epoch [16/100] train_loss: 2.2805, val_loss: 2.5208, lr: 0.010000, 286.47s
# 2024-07-21 11:24:57,624 - INFO - epoch complete!
# 2024-07-21 11:24:57,624 - INFO - evaluating now!
# 2024-07-21 11:25:08,941 - INFO - Epoch [17/100] train_loss: 2.2678, val_loss: 2.5380, lr: 0.010000, 285.28s
# 2024-07-21 11:29:43,469 - INFO - epoch complete!
# 2024-07-21 11:29:43,470 - INFO - evaluating now!
# 2024-07-21 11:29:54,795 - INFO - Epoch [18/100] train_loss: 2.2505, val_loss: 2.4813, lr: 0.010000, 285.85s
# 2024-07-21 11:29:54,841 - INFO - Saved model at 18
# 2024-07-21 11:29:54,841 - INFO - Val loss decrease from 2.5009 to 2.4813, saving to ./libcity/cache/30355/model_cache/HierAttnLstm_PEMS_BAY_epoch18.tar
# 2024-07-21 11:34:29,629 - INFO - epoch complete!
# 2024-07-21 11:34:29,630 - INFO - evaluating now!
# 2024-07-21 11:34:40,941 - INFO - Epoch [19/100] train_loss: 2.2494, val_loss: 2.5074, lr: 0.010000, 286.10s
# 2024-07-21 11:39:15,133 - INFO - epoch complete!
# 2024-07-21 11:39:15,133 - INFO - evaluating now!
# 2024-07-21 11:39:26,375 - INFO - Epoch [20/100] train_loss: 2.2445, val_loss: 2.6237, lr: 0.010000, 285.43s
# 2024-07-21 11:44:00,441 - INFO - epoch complete!
# 2024-07-21 11:44:00,441 - INFO - evaluating now!
# 2024-07-21 11:44:11,785 - INFO - Epoch [21/100] train_loss: 2.2579, val_loss: 2.4941, lr: 0.010000, 285.41s
# 2024-07-21 11:48:47,451 - INFO - epoch complete!
# 2024-07-21 11:48:47,451 - INFO - evaluating now!
# 2024-07-21 11:48:58,761 - INFO - Epoch [22/100] train_loss: 2.2449, val_loss: 2.4986, lr: 0.010000, 286.98s
# 2024-07-21 11:53:33,249 - INFO - epoch complete!
# 2024-07-21 11:53:33,250 - INFO - evaluating now!
# 2024-07-21 11:53:44,525 - INFO - Epoch [23/100] train_loss: 2.2330, val_loss: 2.5993, lr: 0.010000, 285.76s
# 2024-07-21 11:58:19,838 - INFO - epoch complete!
# 2024-07-21 11:58:19,839 - INFO - evaluating now!
# 2024-07-21 11:58:31,112 - INFO - Epoch [24/100] train_loss: 2.2272, val_loss: 2.5435, lr: 0.010000, 286.59s
# 2024-07-21 12:03:05,375 - INFO - epoch complete!
# 2024-07-21 12:03:05,375 - INFO - evaluating now!
# 2024-07-21 12:03:16,572 - INFO - Epoch [25/100] train_loss: 2.2389, val_loss: 2.4932, lr: 0.010000, 285.46s
# 2024-07-21 12:07:50,254 - INFO - epoch complete!
# 2024-07-21 12:07:50,255 - INFO - evaluating now!
# 2024-07-21 12:08:01,541 - INFO - Epoch [26/100] train_loss: 2.2324, val_loss: 2.4909, lr: 0.010000, 284.97s
# 2024-07-21 12:12:36,325 - INFO - epoch complete!
# 2024-07-21 12:12:36,325 - INFO - evaluating now!
# 2024-07-21 12:12:47,666 - INFO - Epoch [27/100] train_loss: 2.3709, val_loss: 2.5600, lr: 0.010000, 286.12s
# 2024-07-21 12:17:21,499 - INFO - epoch complete!
# 2024-07-21 12:17:21,500 - INFO - evaluating now!
# 2024-07-21 12:17:32,860 - INFO - Epoch [28/100] train_loss: 2.3265, val_loss: 2.5451, lr: 0.010000, 285.19s
# 2024-07-21 12:17:32,860 - WARNING - Early stopping at epoch: 28
# 2024-07-21 12:17:32,861 - INFO - Trained totally 29 epochs, average train time is 274.167s, average eval time is 11.296s
# 2024-07-21 12:17:32,887 - INFO - Loaded model at 18
# 2024-07-21 12:17:32,888 - INFO - Saved model at ./libcity/cache/30355/model_cache/HierAttnLstm_PEMS_BAY.m
# 2024-07-21 12:17:32,933 - INFO - Start evaluating ...
# 2024-07-21 12:18:00,758 - INFO - Note that you select the single mode to evaluate!
# 2024-07-21 12:18:00,765 - INFO - Evaluate result is saved at ./libcity/cache/30355/evaluate_cache/2024_07_21_12_18_00_HierAttnLstm_PEMS_BAY.csv
# 2024-07-21 12:18:00,779 - INFO -
#         MAE  MAPE        MSE      RMSE  ...  masked_MSE  masked_RMSE        R2      EVAR
# 1  2.489590   inf  26.797239  5.176605  ...   26.513729     5.149148  0.712707  0.718310
# 2  2.489457   inf  26.795343  5.176422  ...   26.511831     5.148964  0.712723  0.718325
# 3  2.489355   inf  26.793783  5.176271  ...   26.510275     5.148813  0.712737  0.718337
# 4  2.489293   inf  26.792648  5.176162  ...   26.509138     5.148703  0.712747  0.718346
# 5  2.489239   inf  26.791273  5.176029  ...   26.507759     5.148569  0.712759  0.718357
# 6  2.489175   inf  26.789900  5.175896  ...   26.506390     5.148436  0.712771  0.718369
#
# [6 rows x 10 columns]

# %%
# !python run_model.py --task traffic_state_pred --model HierAttnLstm --dataset PEMS_BAY --config_file HierAttnLstm_128_4_2
# Out:
# 2024-07-21 12:18:05,279 - INFO - Log directory: ./libcity/log
# 2024-07-21 12:18:05,280 - INFO - Begin pipeline, task=traffic_state_pred, model_name=HierAttnLstm, dataset_name=PEMS_BAY, exp_id=8128
# 2024-07-21 12:18:05,281 - INFO - {'task': 'traffic_state_pred', 'model': 'HierAttnLstm', 'dataset': 'PEMS_BAY', 'saved_model': True, 'train': True, 'seed': 0, 'input_window': 48, 'output_window': 6, 'device': device(type='cuda', index=0), 'hidden_size': 128, 'num_layers': 4, 'dropout': 0.1, 'natt_hops': 2, 'nfc': 512, 'max_up_len': 80, 'dataset_class': 'TrafficStatePointDataset', 'executor': 'TrafficStateExecutor', 'evaluator': 'TrafficStateEvaluator', 'batch_size': 32, 'cache_dataset': True, 'num_workers': 0, 'pad_with_last_sample': True, 'train_rate': 0.7, 'eval_rate': 0.1, 'scaler': 'minmax01', 'load_external': False, 'normal_external': False, 'ext_scaler': 'none', 'add_time_in_day': False, 'add_day_in_week': False, 'robustness_test': False, 'noise_type': 'gaussian', 'disturb_rate': 0.5, 'noise_mean': [5], 'noise_SD': [10], 'gpu': True, 'gpu_id': 0, 'max_epoch': 100, 'train_loss': 'none', 'epoch': 0, 'learner': 'adam', 'learning_rate': 0.01, 'weight_decay': 0, 'lr_epsilon': 1e-08, 'lr_beta1': 0.9, 'lr_beta2': 0.999, 'lr_alpha': 0.99, 'lr_momentum': 0, 'lr_decay': False, 'lr_scheduler': 'multisteplr', 'lr_decay_ratio': 0.1, 'steps': [5, 20, 40, 70], 'step_size': 10, 'lr_T_max': 30, 'lr_eta_min': 0, 'lr_patience': 10, 'lr_threshold': 0.0001, 'clip_grad_norm': False, 'max_grad_norm': 1.0, 'use_early_stop': True, 'patience': 10, 'log_level': 'INFO', 'log_every': 1, 'load_best_epoch': True, 'hyper_tune': False, 'metrics': ['MAE', 'MAPE', 'MSE', 'RMSE', 'masked_MAE', 'masked_MAPE', 'masked_MSE', 'masked_RMSE', 'R2', 'EVAR'], 'evaluator_mode': 'single', 'save_mode': ['csv'], 'geo': {'including_types': ['Point'], 'Point': {}}, 'rel': {'including_types': ['geo'], 'geo': {'cost': 'num'}}, 'dyna': {'including_types': ['state'], 'state': {'entity_id': 'geo_id', 'traffic_speed': 'num'}}, 'data_col': ['traffic_speed'], 'weight_col': 'cost', 'data_files': ['PEMS_BAY'], 'geo_file': 'PEMS_BAY', 'rel_file': 'PEMS_BAY', 'output_dim': 1, 'time_intervals': 300, 'init_weight_inf_or_zero': 'inf', 'set_weight_link_or_dist': 'dist', 'calculate_weight_adj': True, 'weight_adj_epsilon': 0.1, 'exp_id': 8128}
# self.scaler_type  minmax01
# 2024-07-21 12:18:05,343 - INFO - Loaded file PEMS_BAY.geo, num_nodes=325
# 2024-07-21 12:18:05,353 - INFO - set_weight_link_or_dist: dist
# 2024-07-21 12:18:05,354 - INFO - init_weight_inf_or_zero: inf
# 2024-07-21 12:18:05,367 - INFO - Loaded file PEMS_BAY.rel, shape=(325, 325)
# 2024-07-21 12:18:05,368 - INFO - Start Calculate the weight by Gauss kernel!
# 2024-07-21 12:18:05,371 - INFO - Loading ./libcity/cache/dataset_cache/point_based_PEMS_BAY_48_6_0.7_0.1_minmax01_32_False_False_False_True.npz
# 2024-07-21 12:18:34,968 - INFO - train	x: (36444, 48, 325, 1), y: (36444, 6, 325, 1)
# 2024-07-21 12:18:34,969 - INFO - eval	x: (5206, 48, 325, 1), y: (5206, 6, 325, 1)
# 2024-07-21 12:18:34,969 - INFO - test	x: (10413, 48, 325, 1), y: (10413, 6, 325, 1)
# 2024-07-21 12:18:35,805 - INFO - MinMax01Scaler max: 85.1, min: 0.0
# 2024-07-21 12:18:35,806 - INFO - NoneScaler
# 2024-07-21 12:18:41.545183: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-07-21 12:18:41.596539: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-21 12:18:41.596598: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-21 12:18:41.597998: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-21 12:18:41.605703: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-21 12:18:42.819507: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-07-21 12:18:44,078 - INFO - HierAttnLstm(
#   (lstm_cells): ModuleList(
#     (0): LSTMCell(325, 128)
#     (1-3): 3 x LSTMCell(128, 128)
#   )
#   (hidden_state_pooling): ModuleList(
#     (0-2): 3 x SelfAttentionPooling(
#       (W): Linear(in_features=128, out_features=1, bias=True)
#     )
#   )
#   (cell_state_pooling): ModuleList(
#     (0-2): 3 x SelfAttentionPooling(
#       (W): Linear(in_features=128, out_features=1, bias=True)
#     )
#   )
#   (self_attention): SelfAttention(
#     (ut_dense): Sequential(
#       (0): Linear(in_features=128, out_features=128, bias=True)
#       (1): Tanh()
#     )
#     (et_dense): Linear(in_features=128, out_features=2, bias=True)
#     (softmax): Softmax(dim=-1)
#   )
#   (fc_layer): Sequential(
#     (0): Linear(in_features=256, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=325, bias=True)
#   )
# )
# 2024-07-21 12:18:44,079 - INFO - lstm_cells.0.weight_ih	torch.Size([512, 325])	cuda:0	True
# 2024-07-21 12:18:44,079 - INFO - lstm_cells.0.weight_hh	torch.Size([512, 128])	cuda:0	True
# 2024-07-21 12:18:44,079 - INFO - lstm_cells.0.bias_ih	torch.Size([512])	cuda:0	True
# 2024-07-21 12:18:44,080 - INFO - lstm_cells.0.bias_hh	torch.Size([512])	cuda:0	True
# 2024-07-21 12:18:44,080 - INFO - lstm_cells.1.weight_ih	torch.Size([512, 128])	cuda:0	True
# 2024-07-21 12:18:44,080 - INFO - lstm_cells.1.weight_hh	torch.Size([512, 128])	cuda:0	True
# 2024-07-21 12:18:44,080 - INFO - lstm_cells.1.bias_ih	torch.Size([512])	cuda:0	True
# 2024-07-21 12:18:44,080 - INFO - lstm_cells.1.bias_hh	torch.Size([512])	cuda:0	True
# 2024-07-21 12:18:44,080 - INFO - lstm_cells.2.weight_ih	torch.Size([512, 128])	cuda:0	True
# 2024-07-21 12:18:44,080 - INFO - lstm_cells.2.weight_hh	torch.Size([512, 128])	cuda:0	True
# 2024-07-21 12:18:44,080 - INFO - lstm_cells.2.bias_ih	torch.Size([512])	cuda:0	True
# 2024-07-21 12:18:44,080 - INFO - lstm_cells.2.bias_hh	torch.Size([512])	cuda:0	True
# 2024-07-21 12:18:44,080 - INFO - lstm_cells.3.weight_ih	torch.Size([512, 128])	cuda:0	True
# 2024-07-21 12:18:44,081 - INFO - lstm_cells.3.weight_hh	torch.Size([512, 128])	cuda:0	True
# 2024-07-21 12:18:44,081 - INFO - lstm_cells.3.bias_ih	torch.Size([512])	cuda:0	True
# 2024-07-21 12:18:44,081 - INFO - lstm_cells.3.bias_hh	torch.Size([512])	cuda:0	True
# 2024-07-21 12:18:44,081 - INFO - hidden_state_pooling.0.W.weight	torch.Size([1, 128])	cuda:0	True
# 2024-07-21 12:18:44,081 - INFO - hidden_state_pooling.0.W.bias	torch.Size([1])	cuda:0	True
# 2024-07-21 12:18:44,081 - INFO - hidden_state_pooling.1.W.weight	torch.Size([1, 128])	cuda:0	True
# 2024-07-21 12:18:44,081 - INFO - hidden_state_pooling.1.W.bias	torch.Size([1])	cuda:0	True
# 2024-07-21 12:18:44,081 - INFO - hidden_state_pooling.2.W.weight	torch.Size([1, 128])	cuda:0	True
# 2024-07-21 12:18:44,081 - INFO - hidden_state_pooling.2.W.bias	torch.Size([1])	cuda:0	True
# 2024-07-21 12:18:44,081 - INFO - cell_state_pooling.0.W.weight	torch.Size([1, 128])	cuda:0	True
# 2024-07-21 12:18:44,081 - INFO - cell_state_pooling.0.W.bias	torch.Size([1])	cuda:0	True
# 2024-07-21 12:18:44,082 - INFO - cell_state_pooling.1.W.weight	torch.Size([1, 128])	cuda:0	True
# 2024-07-21 12:18:44,082 - INFO - cell_state_pooling.1.W.bias	torch.Size([1])	cuda:0	True
# 2024-07-21 12:18:44,082 - INFO - cell_state_pooling.2.W.weight	torch.Size([1, 128])	cuda:0	True
# 2024-07-21 12:18:44,082 - INFO - cell_state_pooling.2.W.bias	torch.Size([1])	cuda:0	True
# 2024-07-21 12:18:44,082 - INFO - self_attention.ut_dense.0.weight	torch.Size([128, 128])	cuda:0	True
# 2024-07-21 12:18:44,082 - INFO - self_attention.ut_dense.0.bias	torch.Size([128])	cuda:0	True
# 2024-07-21 12:18:44,082 - INFO - self_attention.et_dense.weight	torch.Size([2, 128])	cuda:0	True
# 2024-07-21 12:18:44,082 - INFO - self_attention.et_dense.bias	torch.Size([2])	cuda:0	True
# 2024-07-21 12:18:44,082 - INFO - fc_layer.0.weight	torch.Size([512, 256])	cuda:0	True
# 2024-07-21 12:18:44,082 - INFO - fc_layer.0.bias	torch.Size([512])	cuda:0	True
# 2024-07-21 12:18:44,083 - INFO - fc_layer.2.weight	torch.Size([325, 512])	cuda:0	True
# 2024-07-21 12:18:44,083 - INFO - fc_layer.2.bias	torch.Size([325])	cuda:0	True
# 2024-07-21 12:18:44,083 - INFO - Total parameter numbers: 945101
# 2024-07-21 12:18:44,083 - INFO - You select `adam` optimizer.
# 2024-07-21 12:18:44,084 - WARNING - Received none train loss func and will use the loss func defined in the model.
# 2024-07-21 12:18:44,084 - INFO - Start training ...
# 2024-07-21 12:18:44,084 - INFO - num_batches:1139
# 2024-07-21 12:24:13,915 - INFO - epoch complete!
# 2024-07-21 12:24:13,916 - INFO - evaluating now!
# 2024-07-21 12:24:27,587 - INFO - Epoch [0/100] train_loss: 5.0600, val_loss: 3.8805, lr: 0.010000, 343.50s
# 2024-07-21 12:24:27,643 - INFO - Saved model at 0
# 2024-07-21 12:24:27,643 - INFO - Val loss decrease from inf to 3.8805, saving to ./libcity/cache/8128/model_cache/HierAttnLstm_PEMS_BAY_epoch0.tar
# 2024-07-21 12:29:59,021 - INFO - epoch complete!
# 2024-07-21 12:29:59,022 - INFO - evaluating now!
# 2024-07-21 12:30:12,816 - INFO - Epoch [1/100] train_loss: 3.1486, val_loss: 3.0495, lr: 0.010000, 345.17s
# 2024-07-21 12:30:12,864 - INFO - Saved model at 1
# 2024-07-21 12:30:12,864 - INFO - Val loss decrease from 3.8805 to 3.0495, saving to ./libcity/cache/8128/model_cache/HierAttnLstm_PEMS_BAY_epoch1.tar
# 2024-07-21 12:35:42,136 - INFO - epoch complete!
# 2024-07-21 12:35:42,137 - INFO - evaluating now!
# 2024-07-21 12:35:55,927 - INFO - Epoch [2/100] train_loss: 2.8717, val_loss: 2.8900, lr: 0.010000, 343.06s
# 2024-07-21 12:35:55,976 - INFO - Saved model at 2
# 2024-07-21 12:35:55,976 - INFO - Val loss decrease from 3.0495 to 2.8900, saving to ./libcity/cache/8128/model_cache/HierAttnLstm_PEMS_BAY_epoch2.tar
# 2024-07-21 12:41:24,710 - INFO - epoch complete!
# 2024-07-21 12:41:24,711 - INFO - evaluating now!
# 2024-07-21 12:41:38,413 - INFO - Epoch [3/100] train_loss: 2.7460, val_loss: 2.8868, lr: 0.010000, 342.44s
# 2024-07-21 12:41:38,461 - INFO - Saved model at 3
# 2024-07-21 12:41:38,462 - INFO - Val loss decrease from 2.8900 to 2.8868, saving to ./libcity/cache/8128/model_cache/HierAttnLstm_PEMS_BAY_epoch3.tar
# 2024-07-21 12:47:08,058 - INFO - epoch complete!
# 2024-07-21 12:47:08,059 - INFO - evaluating now!
# 2024-07-21 12:47:21,742 - INFO - Epoch [4/100] train_loss: 2.6297, val_loss: 2.7650, lr: 0.010000, 343.28s
# 2024-07-21 12:47:21,794 - INFO - Saved model at 4
# 2024-07-21 12:47:21,794 - INFO - Val loss decrease from 2.8868 to 2.7650, saving to ./libcity/cache/8128/model_cache/HierAttnLstm_PEMS_BAY_epoch4.tar
# 2024-07-21 12:52:50,633 - INFO - epoch complete!
# 2024-07-21 12:52:50,633 - INFO - evaluating now!
# 2024-07-21 12:53:04,214 - INFO - Epoch [5/100] train_loss: 2.6244, val_loss: 2.7119, lr: 0.010000, 342.42s
# 2024-07-21 12:53:04,262 - INFO - Saved model at 5
# 2024-07-21 12:53:04,263 - INFO - Val loss decrease from 2.7650 to 2.7119, saving to ./libcity/cache/8128/model_cache/HierAttnLstm_PEMS_BAY_epoch5.tar
# 2024-07-21 12:58:34,023 - INFO - epoch complete!
# 2024-07-21 12:58:34,024 - INFO - evaluating now!
# 2024-07-21 12:58:47,656 - INFO - Epoch [6/100] train_loss: 2.5278, val_loss: 2.7224, lr: 0.010000, 343.39s
# 2024-07-21 13:04:17,201 - INFO - epoch complete!
# 2024-07-21 13:04:17,202 - INFO - evaluating now!
# 2024-07-21 13:04:30,869 - INFO - Epoch [7/100] train_loss: 2.4984, val_loss: 2.6073, lr: 0.010000, 343.21s
# 2024-07-21 13:04:30,921 - INFO - Saved model at 7
# 2024-07-21 13:04:30,922 - INFO - Val loss decrease from 2.7119 to 2.6073, saving to ./libcity/cache/8128/model_cache/HierAttnLstm_PEMS_BAY_epoch7.tar
# 2024-07-21 13:09:59,952 - INFO - epoch complete!
# 2024-07-21 13:09:59,953 - INFO - evaluating now!
# 2024-07-21 13:10:13,665 - INFO - Epoch [8/100] train_loss: 2.4759, val_loss: 2.6744, lr: 0.010000, 342.74s
# 2024-07-21 13:15:42,943 - INFO - epoch complete!
# 2024-07-21 13:15:42,944 - INFO - evaluating now!
# 2024-07-21 13:15:56,754 - INFO - Epoch [9/100] train_loss: 2.4936, val_loss: 2.7488, lr: 0.010000, 343.09s
# 2024-07-21 13:21:25,145 - INFO - epoch complete!
# 2024-07-21 13:21:25,145 - INFO - evaluating now!
# 2024-07-21 13:21:38,848 - INFO - Epoch [10/100] train_loss: 2.4348, val_loss: 2.6222, lr: 0.010000, 342.09s
# 2024-07-21 13:27:07,723 - INFO - epoch complete!
# 2024-07-21 13:27:07,724 - INFO - evaluating now!
# 2024-07-21 13:27:21,390 - INFO - Epoch [11/100] train_loss: 2.4315, val_loss: 2.6165, lr: 0.010000, 342.54s
# 2024-07-21 13:32:50,235 - INFO - epoch complete!
# 2024-07-21 13:32:50,235 - INFO - evaluating now!
# 2024-07-21 13:33:04,055 - INFO - Epoch [12/100] train_loss: 2.4326, val_loss: 2.6672, lr: 0.010000, 342.67s
# 2024-07-21 13:38:33,162 - INFO - epoch complete!
# 2024-07-21 13:38:33,163 - INFO - evaluating now!
# 2024-07-21 13:38:46,849 - INFO - Epoch [13/100] train_loss: 2.4027, val_loss: 2.7144, lr: 0.010000, 342.79s
# 2024-07-21 13:44:14,746 - INFO - epoch complete!
# 2024-07-21 13:44:14,746 - INFO - evaluating now!
# 2024-07-21 13:44:28,409 - INFO - Epoch [14/100] train_loss: 2.3996, val_loss: 2.6482, lr: 0.010000, 341.56s
# 2024-07-21 13:49:58,719 - INFO - epoch complete!
# 2024-07-21 13:49:58,720 - INFO - evaluating now!
# 2024-07-21 13:50:12,345 - INFO - Epoch [15/100] train_loss: 2.3904, val_loss: 2.6164, lr: 0.010000, 343.94s
# 2024-07-21 13:55:39,990 - INFO - epoch complete!
# 2024-07-21 13:55:39,991 - INFO - evaluating now!
# 2024-07-21 13:55:53,680 - INFO - Epoch [16/100] train_loss: 2.3739, val_loss: 2.6335, lr: 0.010000, 341.33s
# 2024-07-21 14:01:22,084 - INFO - epoch complete!
# 2024-07-21 14:01:22,085 - INFO - evaluating now!
# 2024-07-21 14:01:35,747 - INFO - Epoch [17/100] train_loss: 2.3654, val_loss: 2.7191, lr: 0.010000, 342.07s
# 2024-07-21 14:01:35,748 - WARNING - Early stopping at epoch: 17
# 2024-07-21 14:01:35,748 - INFO - Trained totally 18 epochs, average train time is 329.151s, average eval time is 13.697s
# 2024-07-21 14:01:35,776 - INFO - Loaded model at 7
# 2024-07-21 14:01:35,777 - INFO - Saved model at ./libcity/cache/8128/model_cache/HierAttnLstm_PEMS_BAY.m
# 2024-07-21 14:01:35,837 - INFO - Start evaluating ...
# 2024-07-21 14:02:08,323 - INFO - Note that you select the single mode to evaluate!
# 2024-07-21 14:02:08,331 - INFO - Evaluate result is saved at ./libcity/cache/8128/evaluate_cache/2024_07_21_14_02_08_HierAttnLstm_PEMS_BAY.csv
# 2024-07-21 14:02:08,345 - INFO -
#         MAE  MAPE        MSE      RMSE  ...  masked_MSE  masked_RMSE        R2      EVAR
# 1  2.677400   inf  31.006615  5.568358  ...   30.722437     5.542782  0.667579  0.673970
# 2  2.677284   inf  31.005304  5.568241  ...   30.721121     5.542664  0.667587  0.673979
# 3  2.677191   inf  31.004194  5.568141  ...   30.720009     5.542563  0.667596  0.673988
# 4  2.677088   inf  31.002899  5.568025  ...   30.718714     5.542447  0.667608  0.674003
# 5  2.676969   inf  31.001389  5.567889  ...   30.717209     5.542311  0.667621  0.674018
# 6  2.676821   inf  30.999613  5.567729  ...   30.715433     5.542150  0.667636  0.674037
#
# [6 rows x 10 columns]

# %%
# !python run_model.py --task traffic_state_pred --model HierAttnLstm --dataset PEMS_BAY --config_file HierAttnLstm_128_4_3

# %%
# !python run_model.py --task traffic_state_pred --model HierAttnLstm --dataset PEMS_BAY --config_file HierAttnLstm_128_4_4
