# %%
# prompt: mount google drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# prompt: change dir to /content/drive/MyDrive/Hierarchical LSTM for Traffic Prediction/Bigscity-LibCity

# %cd /content/drive/MyDrive/Hierarchical\ LSTM\ for\ Traffic\ Prediction/Bigscity-LibCity
# Out:
# /content/drive/MyDrive/Hierarchical LSTM for Traffic Prediction/Bigscity-LibCity

# %%
# !pip install torch==2.2.2 torchvision==0.17.2 torchaudio==2.2.2
# !pip install ray
# !pip install torchdiffeq
# !pip install einops
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.5/755.5 MB 2.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 105.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 93.2 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...

# %%
hidden_sizes = [64, 128, 256]
num_layers = [2, 3, 4]
natt_hops = [2, 3, 4]

for hs in hidden_sizes:
    for nl in num_layers:
        for nh in natt_hops:
            cmd = f"!python run_model.py --task traffic_state_pred --model HierAttnLstm --dataset METR_LA --hidden_size {hs} --num_layers {nl} --natt_hops {nh}"
            print(cmd)
# Out:
# !python run_model.py --task traffic_state_pred --model HierAttnLstm --dataset METR-LA --hidden_size 64 --num_layers 2 --natt_hops 2
# !python run_model.py --task traffic_state_pred --model HierAttnLstm --dataset METR-LA --hidden_size 64 --num_layers 2 --natt_hops 3
# !python run_model.py --task traffic_state_pred --model HierAttnLstm --dataset METR-LA --hidden_size 64 --num_layers 2 --natt_hops 4
# !python run_model.py --task traffic_state_pred --model HierAttnLstm --dataset METR-LA --hidden_size 64 --num_layers 3 --natt_hops 2
# !python run_model.py --task traffic_state_pred --model HierAttnLstm --dataset METR-LA --hidden_size 64 --num_layers 3 --natt_hops 3
# !python run_model.py --task traffic_state_pred --model HierAttnLstm --dataset METR-LA --hidden_size 64 --num_layers 3 --natt_hops 4
# !python run_model.py --task traffic_state_pred --model HierAttnLstm --dataset METR-LA --hidden_size 64 --num_layers 4 --natt_hops 2
# ...

# %%
# !python run_model.py --task traffic_state_pred --model HierAttnLstm --dataset METR_LA  --config_file HierAttnLstm_256_2_2
# Out:
# 2024-07-21 03:00:15,368 - INFO - Log directory: ./libcity/log
# 2024-07-21 03:00:15,369 - INFO - Begin pipeline, task=traffic_state_pred, model_name=HierAttnLstm, dataset_name=METR_LA, exp_id=6621
# ...

# %%
# !python run_model.py --task traffic_state_pred --model HierAttnLstm --dataset METR_LA  --config_file HierAttnLstm_256_2_3

# %%
# !python run_model.py --task traffic_state_pred --model HierAttnLstm --dataset METR_LA  --config_file HierAttnLstm_256_2_4

# %%
# !python run_model.py --task traffic_state_pred --model HierAttnLstm --dataset METR_LA  --config_file HierAttnLstm_256_3_2

# %%
# !python run_model.py --task traffic_state_pred --model HierAttnLstm --dataset METR_LA  --config_file HierAttnLstm_256_3_3

# %%
# !python run_model.py --task traffic_state_pred --model HierAttnLstm --dataset METR_LA  --config_file HierAttnLstm_256_3_4

# %%
# !python run_model.py --task traffic_state_pred --model HierAttnLstm --dataset METR_LA  --config_file HierAttnLstm_256_4_2

# %%
# !python run_model.py --task traffic_state_pred --model HierAttnLstm --dataset METR_LA  --config_file HierAttnLstm_256_4_3

# %%
# !python run_model.py --task traffic_state_pred --model HierAttnLstm --dataset METR_LA  --config_file HierAttnLstm_256_4_4
